# %% [markdown]
# <a href="https://colab.research.google.com/github/marzinouri/AzeriPipeline/blob/main/Notebooks/POSTagger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prerequisites

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install datasets
# !pip install tokenizers
# !pip install transformers
# !pip install sentencepiece
# !pip install seqeval

# %%
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate

# %%
from datasets import *
from transformers import *
from tokenizers import *
import os
import json
from pathlib import Path
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import math
from seqeval.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Kappa Score Calculation

# %%
with open("/content/drive/MyDrive/Azari/Datasets/POS/POS_part3_person1.csv", "r") as f:
    azb_postags = f.readlines()

annotations1 = []

for pos_tag in azb_postags:
    try:
        id, token, tag = pos_tag.strip().split(",")
        if tag == "NEGP":
            tag = "VERB"
    except:
        print(pos_tag)
    if token == "<start>":
        tags = []
    elif token == "<end>":
        annotations1 += tags
    else:
        tags.append(tag)

with open("/content/drive/MyDrive/Azari/Datasets/POS/POS_part4_person1.csv", "r") as f:
    azb_postags = f.readlines()

for pos_tag in azb_postags:
    try:
        id, token, tag = pos_tag.strip().split(",")
        if tag == "NEGP":
            tag = "VERB"
    except:
        print(pos_tag)
    if token == "<start>":
        tags = []
    elif token == "<end>":
        annotations1 += tags
    else:
        tags.append(tag)

# %%
with open("/content/drive/MyDrive/Azari/Datasets/POS/POS_part3_person2.csv", "r") as f:
    azb_postags = f.readlines()

annotations2 = []

for pos_tag in azb_postags:
    try:
        id, token, tag = pos_tag.strip().split(",")
        if tag == "NEGP":
            tag = "VERB"
    except:
        print(pos_tag)
    if token == "<start>":
        tags = []
    elif token == "<end>":
        annotations2 += tags
    else:
        tags.append(tag)

with open("/content/drive/MyDrive/Azari/Datasets/POS/POS_part4_person2.csv", "r") as f:
    azb_postags = f.readlines()

for pos_tag in azb_postags:
    try:
        id, token, tag = pos_tag.strip().split(",")
        if tag == "NEGP":
            tag = "VERB"
    except:
        print(pos_tag)
    if token == "<start>":
        tags = []
    elif token == "<end>":
        annotations2 += tags
    else:
        tags.append(tag)

# %%
kappa = cohen_kappa_score(annotations1, annotations2)
kappa
# Out:
# 0.9264001853186451

# %% [markdown]
# # Preparing Data

# %%
with open("/content/drive/MyDrive/Azari/Datasets/POS/POS_part3_person1.csv", "r") as f:
    azb_postags = f.readlines()

with open("/content/drive/MyDrive/Azari/Datasets/POS/POS_part4_person2.csv", "r") as f:
    azb_postags += f.readlines()

# %%
tagss = {'NOUN': 0,
  'PUNC': 1,
  'VERB': 2,
  'PRON': 3,
  'ADV': 4,
  'CONJ': 5,
  'DET': 6,
  'NUM': 7,
  'ADJ': 8,
  'QUES': 9,
  'POSTP': 10,
  'INTERJ': 11}
itagss = {v: k for k, v in tagss.items()}

# %%
tagged_sents = []

for pos_tag in azb_postags:
    try:
        id, token, tag = pos_tag.strip().split(",")
        if tag == "NEGP":
            tag = "VERB"
    except:
        print(pos_tag)
    if token == "<start>":
        tokens = []
        tags = []
    elif token == "<end>":
        tagged_sents.append(list(zip(tokens, tags)))
    else:
        tokens.append(token)
        tags.append(tag)

# %%
df = []

for tagged_sent in tagged_sents:
    row_tokens = []
    row_tags = []
    for token, pos_tag in tagged_sent:
        row_tokens.append(token)
        row_tags.append(tagss[pos_tag])
    if len(row_tags) != 0:
        df.append([row_tokens, row_tags])

df_train = pd.DataFrame(df)
df_train.columns = ["tokens", "pos_tags"]

# %%
df_train.head()
# Out:
#                                               tokens  \
# 0  [بیرینین, دامی, آلچاق, گؤرونمه, دوروموندا, اول...
# 1  [گونده‌لیک, گونده‌کی, خبرلری, چاتدیرماق, اوچون...
# 2  [بیلدی, یینه, گؤره, ده, واقتی, اولانا, دک, بیر...
# 3  [بیرسیرا, میللت‌لر, ده‌ییشیک‌لیک‌لرین, قارشی‌س...
# 4  [بیزیم, فیکیرلریمیز, باشقا, دیللرده, ده, یازیل...
#
#                                             pos_tags
# 0      [6, 0, 4, 0, 0, 2, 1, 0, 0, 5, 2, 0, 8, 2, 1]
# 1             [4, 8, 0, 0, 10, 0, 10, 1, 2, 0, 2, 1]
# 2          [0, 0, 10, 5, 0, 8, 4, 6, 8, 0, 10, 2, 1]
# 3                  [6, 0, 0, 0, 2, 1, 6, 0, 0, 2, 1]
# 4  [3, 0, 8, 0, 5, 2, 1, 4, 3, 0, 10, 1, 3, 0, 0,...

# %%
ds_train = Dataset.from_pandas(df_train, features=Features({
                "tokens": Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
                "pos_tags": Sequence(feature=ClassLabel(num_classes=len(tagss), names=list(tagss.keys()), names_file=None, id=None), length=-1, id=None)
            })).train_test_split(train_size=0.8, seed=42)

ds_test = ds_train["test"].train_test_split(train_size=0.5, seed=42)

dataset = DatasetDict({
    "train": ds_train["train"],
    "validation": ds_test["train"],
    "test": ds_test["test"]})
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 160
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 20
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 20
#     })
# })

# %%
label_all_tokens = True

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, padding="max_length", max_length=64, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"pos_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            else:
                label_ids.append(label[word_idx] if label_all_tokens else -100)
            previous_word_idx = word_idx

        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %% [markdown]
# # Finetuning

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification

model_path = "/content/drive/MyDrive/Azari/Models/AzerBert_v2"
pos_model_path = "/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1"
model = AutoModelForTokenClassification.from_pretrained(os.path.join(model_path, "checkpoint-11630"), num_labels=len(tagss))
tokenizer = BertTokenizerFast.from_pretrained(model_path)
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
data_collator = DataCollatorForTokenClassification(tokenizer)
# Out:
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630/config.json
# Model config BertConfig {
#   "_name_or_path": "/content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 64,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.29.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 10000
# }
#
# loading weights file /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630/pytorch_model.bin
# Some weights of the model checkpoint at /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630 were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/config.json
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/config.json
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]

# %%
args = TrainingArguments(
    output_dir=pos_model_path,
    evaluation_strategy = "epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    overwrite_output_dir=True,
    resume_from_checkpoint=pos_model_path,
    load_best_model_at_end=True,
    learning_rate=2e-5,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_train_epochs=20,
    weight_decay=0.01,
    save_total_limit=1
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
metric = load_metric("seqeval")
# Out:
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]

# %%
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    # Remove ignored index (special tokens)
    true_predictions = [
        [itagss[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [itagss[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 160
#   Num Epochs = 20
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 60
#   Number of trainable parameters = 92,795,916
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 02:51, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.084100</td>
#       <td>1.180312</td>
#       <td>0.454545</td>
#       <td>0.209924</td>
#       <td>0.287206</td>
#       <td>0.695255</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.145300</td>
#       <td>0.930381</td>
#       <td>0.480583</td>
#       <td>0.377863</td>
#       <td>0.423077</td>
#       <td>0.762774</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.898300</td>
#       <td>0.762076</td>
#       <td>0.564103</td>
#       <td>0.503817</td>
#       <td>0.532258</td>
#       <td>0.804745</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.740600</td>
#       <td>0.665376</td>
#       <td>0.637131</td>
#       <td>0.576336</td>
#       <td>0.605210</td>
#       <td>0.837591</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.645100</td>
#       <td>0.627103</td>
#       <td>0.618677</td>
#       <td>0.606870</td>
#       <td>0.612717</td>
#       <td>0.837591</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.566800</td>
#       <td>0.589029</td>
#       <td>0.624506</td>
#       <td>0.603053</td>
#       <td>0.613592</td>
#       <td>0.837591</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.508500</td>
#       <td>0.567340</td>
#       <td>0.658730</td>
#       <td>0.633588</td>
#       <td>0.645914</td>
#       <td>0.852190</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.474600</td>
#       <td>0.544993</td>
#       <td>0.657480</td>
#       <td>0.637405</td>
#       <td>0.647287</td>
#       <td>0.854015</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.431200</td>
#       <td>0.543777</td>
#       <td>0.637405</td>
#       <td>0.637405</td>
#       <td>0.637405</td>
#       <td>0.844891</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.386200</td>
#       <td>0.525656</td>
#       <td>0.661417</td>
#       <td>0.641221</td>
#       <td>0.651163</td>
#       <td>0.854015</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.354400</td>
#       <td>0.515716</td>
#       <td>0.674510</td>
#       <td>0.656489</td>
#       <td>0.665377</td>
#       <td>0.861314</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.339500</td>
#       <td>0.510165</td>
#       <td>0.692913</td>
#       <td>0.671756</td>
#       <td>0.682171</td>
#       <td>0.868613</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.312300</td>
#       <td>0.505220</td>
#       <td>0.686047</td>
#       <td>0.675573</td>
#       <td>0.680769</td>
#       <td>0.868613</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.296300</td>
#       <td>0.502781</td>
#       <td>0.687023</td>
#       <td>0.687023</td>
#       <td>0.687023</td>
#       <td>0.868613</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.276300</td>
#       <td>0.497528</td>
#       <td>0.683398</td>
#       <td>0.675573</td>
#       <td>0.679463</td>
#       <td>0.868613</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.267800</td>
#       <td>0.500249</td>
#       <td>0.700000</td>
#       <td>0.694656</td>
#       <td>0.697318</td>
#       <td>0.874088</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.260300</td>
#       <td>0.502002</td>
#       <td>0.692015</td>
#       <td>0.694656</td>
#       <td>0.693333</td>
#       <td>0.872263</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.245000</td>
#       <td>0.501566</td>
#       <td>0.700000</td>
#       <td>0.694656</td>
#       <td>0.697318</td>
#       <td>0.870438</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.248900</td>
#       <td>0.500422</td>
#       <td>0.700000</td>
#       <td>0.694656</td>
#       <td>0.697318</td>
#       <td>0.872263</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.234100</td>
#       <td>0.500432</td>
#       <td>0.700000</td>
#       <td>0.694656</td>
#       <td>0.697318</td>
#       <td>0.872263</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-3
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-3/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-3/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-3/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-3/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-6
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-6/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-6/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-6/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-6/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-3] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-9
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-9/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-9/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-9/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-9/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-6] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-12
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-12/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-12/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-12/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-12/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-9] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-15
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-15/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-15/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-15/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-15/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-12] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-18
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-18/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-18/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-18/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-18/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-15] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-21
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-21/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-18] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-24
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-24/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-24/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-24/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-24/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-21] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-27
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-27/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-27/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-27/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-27/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-24] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-30
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-30/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-30/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-30/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-30/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-27] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-33
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-33/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-33/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-33/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-33/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-30] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-36
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-36/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-36/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-36/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-36/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-33] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-39
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-39/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-39/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-39/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-39/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-36] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-42
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-42/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-42/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-42/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-42/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-39] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-45
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-45/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-45/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-45/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-45/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-42] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-48
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-48/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-48/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-48/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-48/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-51
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-51/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-51/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-51/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-51/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-48] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-54
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-54/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-54/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-54/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-54/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-51] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-57
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-57/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-57/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-57/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-57/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-54] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-60
# Configuration saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-60/config.json
# Model weights saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-60/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-60/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-60/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-57] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-45 (score: 0.4975282549858093).
# Deleting older checkpoint [/content/drive/MyDrive/Azari/Models/POS_TAGGER_v1/checkpoint-60] due to args.save_total_limit
# TrainOutput(global_step=60, training_loss=0.5357698023319244, metrics={'train_runtime': 174.9764, 'train_samples_per_second': 18.288, 'train_steps_per_second': 0.343, 'total_flos': 104528152166400.0, 'train_loss': 0.5357698023319244, 'epoch': 20.0})

# %%
# our tags
predictions, labels, _ = trainer.predict(tokenized_dataset["test"])
predictions = np.argmax(predictions, axis=2)

# Remove ignored index (special tokens)
true_predictions = [
    [itagss[p] for (p, l) in zip(prediction, label) if l != -100]
    for prediction, label in zip(predictions, labels)
]
true_labels = [
    [itagss[l] for (p, l) in zip(prediction, label) if l != -100]
    for prediction, label in zip(predictions, labels)
]

results = metric.compute(predictions=true_predictions, references=true_labels)
print(results)
print(classification_report(true_labels, true_predictions))
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: tokens, pos_tags. If tokens, pos_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 64
# {'DJ': {'precision': 0.5714285714285714, 'recall': 0.4444444444444444, 'f1': 0.5, 'number': 18}, 'DV': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1': 0.6666666666666666, 'number': 9}, 'ERB': {'precision': 0.6341463414634146, 'recall': 0.7878787878787878, 'f1': 0.7027027027027027, 'number': 33}, 'ET': {'precision': 0.9, 'recall': 0.75, 'f1': 0.8181818181818182, 'number': 12}, 'ONJ': {'precision': 0.8888888888888888, 'recall': 0.8888888888888888, 'f1': 0.8888888888888888, 'number': 9}, 'OSTP': {'precision': 1.0, 'recall': 0.8333333333333334, 'f1': 0.9090909090909091, 'number': 6}, 'OUN': {'precision': 0.5972222222222222, 'recall': 0.589041095890411, 'f1': 0.593103448275862, 'number': 73}, 'RON': {'precision': 0.6, 'recall': 0.5454545454545454, 'f1': 0.5714285714285713, 'number': 11}, 'UM': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'UNC': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 47}, 'overall_precision': 0.728110599078341, 'overall_recall': 0.7181818181818181, 'overall_f1': 0.723112128146453, 'overall_accuracy': 0.861995753715499}
#               precision    recall  f1-score   support
#
#           DJ       0.57      0.44      0.50        18
#           DV       0.67      0.67      0.67         9
#          ERB       0.63      0.79      0.70        33
#           ET       0.90      0.75      0.82        12
#          ONJ       0.89      0.89      0.89         9
#         OSTP       1.00      0.83      0.91         6
#          OUN       0.60      0.59      0.59        73
#          RON       0.60      0.55      0.57        11
#           UM       0.00      0.00      0.00         2
#          UNC       1.00      1.00      1.00        47
#
#    micro avg       0.73      0.72      0.72       220
#    macro avg       0.69      0.65      0.67       220
# weighted avg       0.72      0.72      0.72       220

# %% [markdown]
# # Inference

# %%
modelc = model.to('cpu')
pos_tagger = pipeline("token-classification", model=modelc, tokenizer=tokenizer)

# %%
pos_tagger("حالین نجوردی؟")
