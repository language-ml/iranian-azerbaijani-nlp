# %% [markdown]
# <a href="https://colab.research.google.com/github/marzinouri/AzeriPipeline/blob/main/BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Acknowledgment: This portion of the code is based on the work available at [The Python Code](https://www.thepythoncode.com/article/pretraining-bert-huggingface-transformers-in-python).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install and Import Requirements

# %%
# %%capture
# !pip install datasets
# !pip install tokenizers
# !pip install transformers
# !pip install sentencepiece

# %%
from datasets import *
from transformers import *
from tokenizers import *
import os
import json
from pathlib import Path
import pandas as pd
from tqdm.auto import tqdm
import math
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/generation_tf_utils.py:24: FutureWarning: Importing `TFGenerationMixin` from `src/transformers/generation_tf_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import TFGenerationMixin` instead.
#   warnings.warn(

# %% [markdown]
# # Load Data

# %%
def load_data_to_df(path):
    """
    Load dataset
    """

    # load data into a DataFrame object:
    df = pd.DataFrame()
    sents = []

    with open(path, "r") as f:
        lines = f.readlines()
    # lines = Path(path).open(encoding="utf-8").read().strip().split("\n")
    for line in lines:
        if line.strip() != "":
            sents.append(line.strip())
    df["text"] = sents
    return df

# %%
src_path = "/content/drive/MyDrive/Azari/Preprocessed_Datasets/Monolingual/ALL_v4.txt"
df = load_data_to_df(src_path)

# %%
from datasets import Dataset

azeri_dataset = Dataset.from_pandas(df)
azeri_dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 1323130
# })

# %%
data_train_test = azeri_dataset.train_test_split(test_size=0.1)
data_train, data_test = data_train_test["train"], data_train_test["test"]

data_train, data_test
# Out:
# (Dataset({
#      features: ['text'],
#      num_rows: 1190817
#  }), Dataset({
#      features: ['text'],
#      num_rows: 132313
#  }))

# %%
def dataset_to_text(dataset, output_filename="data.txt"):
  """Utility function to save dataset text to disk,
  useful for using the texts to train the tokenizer
  (as the tokenizer accepts files)"""
  with open(output_filename, "w") as f:
    for t in dataset["text"]:
      print(t, file=f)

dataset_to_text(data_train, "train.txt")
dataset_to_text(data_test, "test.txt")

# %% [markdown]
# # Tokenizer

# %%
from pathlib import Path
from tokenizers import BertWordPieceTokenizer

special_tokens = [
  "[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]", "<S>", "<T>"
]

files = ["train.txt"]
vocab_size = 10000
max_length = 64
truncate_longer_samples = True

# %%
# initialize the WordPiece tokenizer
tokenizer = BertWordPieceTokenizer()
# train the tokenizer
tokenizer.train(files=files, vocab_size=vocab_size, special_tokens=special_tokens)
# enable truncation up to the maximum 64 tokens
tokenizer.enable_truncation(max_length=max_length)

# %%
model_path = "/content/drive/MyDrive/Azari/Models/AzerBert_v2"

# %%
# make the directory if not already there
if not os.path.isdir(model_path):
  os.mkdir(model_path)
# save the tokenizer
tokenizer.save_model(model_path)
# tokenizer config
with open(os.path.join(model_path, "config.json"), "w") as f:
  tokenizer_cfg = {
      "do_lower_case": True,
      "unk_token": "[UNK]",
      "sep_token": "[SEP]",
      "pad_token": "[PAD]",
      "cls_token": "[CLS]",
      "mask_token": "[MASK]",
      "model_max_length": max_length,
      "max_len": max_length,
  }
  json.dump(tokenizer_cfg, f)

# %%
tokenizer = BertTokenizerFast.from_pretrained(model_path)
# Out:
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/config.json
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/config.json

# %%
def encode_with_truncation(examples):
  """Mapping function to tokenize the sentences passed with truncation"""
  return tokenizer(examples["text"], truncation=True, padding="max_length",
                   max_length=max_length, return_special_tokens_mask=True)

def encode_without_truncation(examples):
  """Mapping function to tokenize the sentences passed without truncation"""
  return tokenizer(examples["text"], return_special_tokens_mask=True)

encode = encode_with_truncation if truncate_longer_samples else encode_without_truncation

# tokenizing the train dataset
train_dataset = data_train.map(encode, batched=True)
# tokenizing the test dataset
test_dataset = data_test.map(encode, batched=True)
# Out:
#   0%|          | 0/1191 [00:00<?, ?ba/s]
#   0%|          | 0/133 [00:00<?, ?ba/s]

# %%
if truncate_longer_samples:
  train_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])
  test_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])
else:
  test_dataset.set_format(columns=["input_ids", "attention_mask", "special_tokens_mask"])
  train_dataset.set_format(columns=["input_ids", "attention_mask", "special_tokens_mask"])

# %%
from itertools import chain

def group_texts(examples):
    concatenated_examples = {k: list(chain(*examples[k])) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    if total_length >= max_length:
        total_length = (total_length // max_length) * max_length
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + max_length] for i in range(0, total_length, max_length)]
        for k, t in concatenated_examples.items()
    }
    return result

if not truncate_longer_samples:
  train_dataset = train_dataset.map(group_texts, batched=True,
                                    desc=f"Grouping texts in chunks of {max_length}")
  test_dataset = test_dataset.map(group_texts, batched=True,
                                  desc=f"Grouping texts in chunks of {max_length}")
  # convert them from lists to torch tensors
  train_dataset.set_format("torch")
  test_dataset.set_format("torch")

# %%
len(train_dataset), len(test_dataset)
# Out:
# (1190817, 132313)

# %% [markdown]
# # Model

# %%
# initialize the model with the config
model_config = BertConfig(vocab_size=vocab_size, max_position_embeddings=max_length)
model = BertForMaskedLM(config=model_config)

# %%
# initialize the data collator, randomly masking 15% of the tokens for MLM
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)

# %%
training_args = TrainingArguments(
    output_dir=model_path,
    evaluation_strategy="epoch",
    overwrite_output_dir=True,
    num_train_epochs=10,
    per_device_train_batch_size=128,
    gradient_accumulation_steps=8,
    per_device_eval_batch_size=128,
    # logging_steps=10,
    logging_strategy="epoch",
    save_strategy="epoch",
    # save_steps=10,
    resume_from_checkpoint=model_path,
    load_best_model_at_end=True,
    save_total_limit=1,
    )
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
)

# %%
trainer.train()

# %% [markdown]
# # Load The Best Checkpoint

# %%
# load the model checkpoint
model = BertForMaskedLM.from_pretrained(os.path.join(model_path, "checkpoint-11630"))
# load the tokenizer
tokenizer = BertTokenizerFast.from_pretrained(model_path)
# Out:
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 64,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 10000
# }
#
# loading weights file /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForMaskedLM.
#
# All the weights of BertForMaskedLM were initialized from the model checkpoint at /content/drive/MyDrive/Azari/Models/AzerBert_v2/checkpoint-11630.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForMaskedLM for predictions without further training.
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/config.json
# loading configuration file /content/drive/MyDrive/Azari/Models/AzerBert_v2/config.json

# %%
eval_results = trainer.evaluate()
print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text, special_tokens_mask. If text, special_tokens_mask are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 132313
#   Batch size = 128
#     <div>
#
#       <progress value='1034' max='1034' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1034/1034 08:59]
#     </div>
# Perplexity: 48.05

# %%
fill_mask = pipeline("fill-mask", model=model, tokenizer=tokenizer)

# %%
# perform predictions
import random

for example in data_test["text"][:100]:
    print("Input: ", example)
    arr_example = example.split(" ")
    index = random.randint(0, len(arr_example)-1)
    print("Masked Word: ", arr_example[index])
    arr_example[index] = "[MASK]"
    masked_example = f" ".join(arr_example)
    # print(masked_example)

    try:
        a = fill_mask(masked_example, arr_example)
    except:
        continue
    for prediction in a:
        print("Predicted Word: ", prediction["token_str"])
        print(f"{prediction['sequence']}, confidence: {prediction['score']}")
    print("="*50)
# Out:
# Input:  بو افاده ، بو شێلتاقلێق بؤیوک مسولیت یارادا بیلر .
# Masked Word:  بو
# Predicted Word:  بو
# بو افاده ، بو شێلتاقلێق بویوک مسولیت یارادا بیلر., confidence: 0.04148092120885849
# Predicted Word:  سیاسی
# بو افاده ، سیاسی شێلتاقلێق بویوک مسولیت یارادا بیلر., confidence: 0.023639466613531113
# Predicted Word:  یينی
# بو افاده ، یينی شێلتاقلێق بویوک مسولیت یارادا بیلر., confidence: 0.020893214270472527
# Predicted Word:  ینی
# بو افاده ، ینی شێلتاقلێق بویوک مسولیت یارادا بیلر., confidence: 0.018106702715158463
# Predicted Word:  بۆتۆن
# بو افاده ، بۆتۆن شێلتاقلێق بویوک مسولیت یارادا بیلر., confidence: 0.017479099333286285
# ==================================================
# Input:  أللرین ایله بالینجیوین توْخونوشوندان ، ده‌ریسی ایسلانمیش ناغارا سسی قالخیر .
# Masked Word:  أللرین
# Predicted Word:  الی
# الی ایله بالینجیوین توخونوشوندان ، دهریسی ایسلانمیش ناغارا سسی قالخیر., confidence: 0.05082245543599129
# Predicted Word:  جی
# جی ایله بالینجیوین توخونوشوندان ، دهریسی ایسلانمیش ناغارا سسی قالخیر., confidence: 0.02185274474322796
# Predicted Word:  اللری
# اللری ایله بالینجیوین توخونوشوندان ، دهریسی ایسلانمیش ناغارا سسی قالخیر., confidence: 0.021377308294177055
# Predicted Word:  اونون
# اونون ایله بالینجیوین توخونوشوندان ، دهریسی ایسلانمیش ناغارا سسی قالخیر., confidence: 0.02134774811565876
# Predicted Word:  گوزو
# گوزو ایله بالینجیوین توخونوشوندان ، دهریسی ایسلانمیش ناغارا سسی قالخیر., confidence: 0.012534950859844685
# ==================================================
# Input:  بزن داشێنما زامانێ یئره دۆشن چؤرک یئنیدن ماشێنا یۆکلهنهرک ماغازالارا پایلانیلیر .
# Masked Word:  .
# Predicted Word:  .
# بزن داشێنما زامانێ یيره دۆشن چورک یينیدن ماشێنا یۆکلهنهرک ماغازالارا پایلانیلیر., confidence: 0.9994359612464905
# Predicted Word:  !
# بزن داشێنما زامانێ یيره دۆشن چورک یينیدن ماشێنا یۆکلهنهرک ماغازالارا پایلانیلیر!, confidence: 0.00030852388590574265
# Predicted Word:  ؟
# بزن داشێنما زامانێ یيره دۆشن چورک یينیدن ماشێنا یۆکلهنهرک ماغازالارا پایلانیلیر ؟, confidence: 0.00022001421893946826
# Predicted Word:  ،
# بزن داشێنما زامانێ یيره دۆشن چورک یينیدن ماشێنا یۆکلهنهرک ماغازالارا پایلانیلیر ،, confidence: 7.601856282235531e-07
# Predicted Word:  ##اق
# بزن داشێنما زامانێ یيره دۆشن چورک یينیدن ماشێنا یۆکلهنهرک ماغازالارا پایلانیلیراق, confidence: 2.6477235337551974e-07
# ==================================================
# Input:  پرئزیدئنت بوندان اول مینیمیم امکهاققینین ، داها سونرا مۆعلم وه حکیملرین ماشلارێنێن فایز آرتیریلماسی ایله باغلێ سرنجام وئریب .
# Masked Word:  ،
# Predicted Word:  سایی
# پريزیدينت بوندان اول مینیمیم امکهاققینین سایی داها سونرا مۆعلم وه حکیملرین ماشلارێنێن فایز ارتیریلماسی ایله باغلێ سرنجام ويریب., confidence: 0.11545101553201675
# Predicted Word:  حجمی
# پريزیدينت بوندان اول مینیمیم امکهاققینین حجمی داها سونرا مۆعلم وه حکیملرین ماشلارێنێن فایز ارتیریلماسی ایله باغلێ سرنجام ويریب., confidence: 0.021624378859996796
# Predicted Word:  ارتماسێ
# پريزیدينت بوندان اول مینیمیم امکهاققینین ارتماسێ داها سونرا مۆعلم وه حکیملرین ماشلارێنێن فایز ارتیریلماسی ایله باغلێ سرنجام ويریب., confidence: 0.013530454598367214
# Predicted Word:  فعالیتی
# پريزیدينت بوندان اول مینیمیم امکهاققینین فعالیتی داها سونرا مۆعلم وه حکیملرین ماشلارێنێن فایز ارتیریلماسی ایله باغلێ سرنجام ويریب., confidence: 0.012959570623934269
# Predicted Word:  یارادیلماسی
# پريزیدينت بوندان اول مینیمیم امکهاققینین یارادیلماسی داها سونرا مۆعلم وه حکیملرین ماشلارێنێن فایز ارتیریلماسی ایله باغلێ سرنجام ويریب., confidence: 0.012565975077450275
# ==================================================
# Input:  آرمینا آرتێق رومانێن ولایتیدیگی .
# Masked Word:  آرتێق
# Predicted Word:  ##ر
# ارمینار رومانێن ولایتیدیگی., confidence: 0.25168538093566895
# Predicted Word:  ##ب
# ارمیناب رومانێن ولایتیدیگی., confidence: 0.08426924049854279
# Predicted Word:  ##ری
# ارمیناری رومانێن ولایتیدیگی., confidence: 0.076140858232975
# Predicted Word:  ##ت
# ارمینات رومانێن ولایتیدیگی., confidence: 0.0739942342042923
# Predicted Word:  ##ل
# ارمینال رومانێن ولایتیدیگی., confidence: 0.04237598180770874
# ==================================================
# Input:  داخلی سئکرئسییا ووزیلرینین افراز ائتدیگی هورمونلار .
# Masked Word:  ائتدیگی
# Predicted Word:  ##لاری
# داخلی سيکريسییا ووزیلرینین افرازلاری هورمونلار., confidence: 0.052068646997213364
# Predicted Word:  ##لار
# داخلی سيکريسییا ووزیلرینین افرازلار هورمونلار., confidence: 0.04420781508088112
# Predicted Word:  ##چیسی
# داخلی سيکريسییا ووزیلرینین افرازچیسی هورمونلار., confidence: 0.028830138966441154
# Predicted Word:  ##ی
# داخلی سيکريسییا ووزیلرینین افرازی هورمونلار., confidence: 0.021976906806230545
# Predicted Word:  ##لارێ
# داخلی سيکريسییا ووزیلرینین افرازلارێ هورمونلار., confidence: 0.0194590725004673
# ==================================================
# Input:  آتالارێنێز ایندی هارادادێر ؟
# Masked Word:  هارادادێر
# Predicted Word:  ##می
# اتالارێنێز ایندیمی ؟, confidence: 0.1709580272436142
# Predicted Word:  ##دیر
# اتالارێنێز ایندیدیر ؟, confidence: 0.04245728626847267
# Predicted Word:  ندیر
# اتالارێنێز ایندی ندیر ؟, confidence: 0.028420178219676018
# Predicted Word:  ##سن
# اتالارێنێز ایندیسن ؟, confidence: 0.026898499578237534
# Predicted Word:  وار
# اتالارێنێز ایندی وار ؟, confidence: 0.023671863600611687
# ==================================================
# Input:  بیلدیریلیر کی ، شاهنین ائویندن تاپێلان چئرتیوژلار اساسێندا آختارێشلار آکپ نین آنکارآداقێ مرکزی قرارگاهێنێن وه باش نازرین ائوینین هندهورینده ده آپارێلێر .
# Masked Word:  وه
# Predicted Word:  وه
# بیلدیریلیر کی ، شاهنین ايویندن تاپێلان چيرتیوژلار اساسێندا اختارێشلار اکپ نین انکاراداقێ مرکزی قرارگاهێنێن وه باش نازرین ايوینین هندهورینده ده اپارێلێر., confidence: 0.037902478128671646
# Predicted Word:  رحبری
# بیلدیریلیر کی ، شاهنین ايویندن تاپێلان چيرتیوژلار اساسێندا اختارێشلار اکپ نین انکاراداقێ مرکزی قرارگاهێنێن رحبری باش نازرین ايوینین هندهورینده ده اپارێلێر., confidence: 0.026865709573030472
# Predicted Word:  سدری
# بیلدیریلیر کی ، شاهنین ايویندن تاپێلان چيرتیوژلار اساسێندا اختارێشلار اکپ نین انکاراداقێ مرکزی قرارگاهێنێن سدری باش نازرین ايوینین هندهورینده ده اپارێلێر., confidence: 0.022656811401247978
# Predicted Word:  بیرینده
# بیلدیریلیر کی ، شاهنین ايویندن تاپێلان چيرتیوژلار اساسێندا اختارێشلار اکپ نین انکاراداقێ مرکزی قرارگاهێنێن بیرینده باش نازرین ايوینین هندهورینده ده اپارێلێر., confidence: 0.020985642448067665
# Predicted Word:  اۆزۆۆ
# بیلدیریلیر کی ، شاهنین ايویندن تاپێلان چيرتیوژلار اساسێندا اختارێشلار اکپ نین انکاراداقێ مرکزی قرارگاهێنێن اۆزۆۆ باش نازرین ايوینین هندهورینده ده اپارێلێر., confidence: 0.016403254121541977
# ==================================================
# Input:  چوخلارێنێن ائیبینی آچێر .
# Masked Word:  .
# Predicted Word:  .
# چوخلارێنێن ايیبینی اچێر., confidence: 0.9993495345115662
# Predicted Word:  !
# چوخلارێنێن ايیبینی اچێر!, confidence: 0.0005138515261933208
# Predicted Word:  ؟
# چوخلارێنێن ايیبینی اچێر ؟, confidence: 0.00010963006207020953
# Predicted Word:  ##اق
# چوخلارێنێن ايیبینی اچێراق, confidence: 2.3701882412296982e-07
# Predicted Word:  ،
# چوخلارێنێن ايیبینی اچێر ،, confidence: 1.6555752324620698e-07
# ==================================================
# Input:  نادر خان سوسوب .
# Masked Word:  .
# Predicted Word:  .
# نادر خان سوسوب., confidence: 0.9996423721313477
# Predicted Word:  !
# نادر خان سوسوب!, confidence: 0.00018781941616907716
# Predicted Word:  ؟
# نادر خان سوسوب ؟, confidence: 0.00013762501475866884
# Predicted Word:  ##اق
# نادر خان سوسوباق, confidence: 1.666086291152169e-07
# Predicted Word:  ##م
# نادر خان سوسوبم, confidence: 9.41376399055116e-08
# ==================================================
# Input:  اونا قیقاجی باخدیغیمدا سئودایا دوشدوگونو آنلادیم .
# Masked Word:  قیقاجی
# Predicted Word:  گوره
# اونا گوره باخدیغیمدا سيودایا دوشدوگونو انلادیم., confidence: 0.11727771162986755
# Predicted Word:  من
# اونا من باخدیغیمدا سيودایا دوشدوگونو انلادیم., confidence: 0.06565483659505844
# Predicted Word:  طرف
# اونا طرف باخدیغیمدا سيودایا دوشدوگونو انلادیم., confidence: 0.05869746208190918
# Predicted Word:  ده
# اونا ده باخدیغیمدا سيودایا دوشدوگونو انلادیم., confidence: 0.03395794704556465
# Predicted Word:  بيله
# اونا بيله باخدیغیمدا سيودایا دوشدوگونو انلادیم., confidence: 0.027616146951913834
# ==================================================
# Input:  امهلی فایدا قازانما منتیقینین داشیییجیسیدیر .
# Masked Word:  داشیییجیسیدیر
# Predicted Word:  نتیجهسیدیر
# امهلی فایدا قازانما منتیقینین نتیجهسیدیر., confidence: 0.15958520770072937
# Predicted Word:  ##دیر
# امهلی فایدا قازانما منتیقینیندیر., confidence: 0.03935485705733299
# Predicted Word:  ادێ
# امهلی فایدا قازانما منتیقینین ادێ., confidence: 0.03716432675719261
# Predicted Word:  ##دن
# امهلی فایدا قازانما منتیقینیندن., confidence: 0.02014668844640255
# Predicted Word:  یوخدور
# امهلی فایدا قازانما منتیقینین یوخدور., confidence: 0.018964717164635658
# ==================================================
# Input:  توفارقانلێ آبباس تفلیس شهرینی محبتله تریفلهمیشدی .
# Masked Word:  شهرینی
# Predicted Word:  ##ه
# توفارقانلێ ابباس تفلیسه محبتله تریفلهمیشدی., confidence: 0.40682899951934814
# Predicted Word:  ##ده
# توفارقانلێ ابباس تفلیسده محبتله تریفلهمیشدی., confidence: 0.36679282784461975
# Predicted Word:  ##ی
# توفارقانلێ ابباس تفلیسی محبتله تریفلهمیشدی., confidence: 0.04069320112466812
# Predicted Word:  ##دن
# توفارقانلێ ابباس تفلیسدن محبتله تریفلهمیشدی., confidence: 0.03714749962091446
# Predicted Word:  ##له
# توفارقانلێ ابباس تفلیسله محبتله تریفلهمیشدی., confidence: 0.011710581369698048
# ==================================================
# Input:  سن بو گئجه منیم !
# Masked Word:  !
# Predicted Word:  .
# سن بو گيجه منیم., confidence: 0.6278212070465088
# Predicted Word:  !
# سن بو گيجه منیم!, confidence: 0.23381386697292328
# Predicted Word:  ؟
# سن بو گيجه منیم ؟, confidence: 0.13671189546585083
# Predicted Word:  باخ
# سن بو گيجه منیم باخ, confidence: 1.0385345376562327e-05
# Predicted Word:  ان
# سن بو گيجه منیم ان, confidence: 7.790008567098994e-06
# ==================================================
# Input:  ائتنیک تمیزلهمه سیاستی باش وئرمیشدیر .
# Masked Word:  ائتنیک
# Predicted Word:  اونون
# اونون تمیزلهمه سیاستی باش ويرمیشدیر., confidence: 0.04830600321292877
# Predicted Word:  اونلارێن
# اونلارێن تمیزلهمه سیاستی باش ويرمیشدیر., confidence: 0.03714627027511597
# Predicted Word:  غیری
# غیری تمیزلهمه سیاستی باش ويرمیشدیر., confidence: 0.0364953950047493
# Predicted Word:  اذربایجاندا
# اذربایجاندا تمیزلهمه سیاستی باش ويرمیشدیر., confidence: 0.032389264553785324
# Predicted Word:  بورادا
# بورادا تمیزلهمه سیاستی باش ويرمیشدیر., confidence: 0.027974732220172882
# ==================================================
# Input:  اونون سؤزلرینه گؤره ، اؤزبال چئلیک بورو مالیه وه تئخنیکی باخێمدان نابوککو نون بورولارا اولان احتیاجینی اؤدهمک اقتداریندا اولان شرکتدیر .
# Masked Word:  گؤره
# Predicted Word:  گوره
# اونون سوزلرینه گوره ، اوزبال چيلیک بورو مالیه وه تيخنیکی باخێمدان نابوککو نون بورولارا اولان احتیاجینی اودهمک اقتداریندا اولان شرکتدیر., confidence: 0.9975334405899048
# Predicted Word:  اساسا
# اونون سوزلرینه اساسا ، اوزبال چيلیک بورو مالیه وه تيخنیکی باخێمدان نابوککو نون بورولارا اولان احتیاجینی اودهمک اقتداریندا اولان شرکتدیر., confidence: 0.0009466706542298198
# Predicted Word:  باخمایاراق
# اونون سوزلرینه باخمایاراق ، اوزبال چيلیک بورو مالیه وه تيخنیکی باخێمدان نابوککو نون بورولارا اولان احتیاجینی اودهمک اقتداریندا اولان شرکتدیر., confidence: 0.0006267466815188527
# Predicted Word:  کی
# اونون سوزلرینه کی ، اوزبال چيلیک بورو مالیه وه تيخنیکی باخێمدان نابوککو نون بورولارا اولان احتیاجینی اودهمک اقتداریندا اولان شرکتدیر., confidence: 9.89860127447173e-05
# Predicted Word:  صبب
# اونون سوزلرینه صبب ، اوزبال چيلیک بورو مالیه وه تيخنیکی باخێمدان نابوککو نون بورولارا اولان احتیاجینی اودهمک اقتداریندا اولان شرکتدیر., confidence: 5.6035798479570076e-05
# ==================================================
# Input:  اولدوز اولدوز ناخێش اولام .
# Masked Word:  اولدوز
# Predicted Word:  ##لار
# اولدوزلار ناخێش اولام., confidence: 0.2038310319185257
# Predicted Word:  ##ا
# اولدوزا ناخێش اولام., confidence: 0.10438238084316254
# Predicted Word:  ##لارا
# اولدوزلارا ناخێش اولام., confidence: 0.08264566212892532
# Predicted Word:  ##و
# اولدوزو ناخێش اولام., confidence: 0.0689392015337944
# Predicted Word:  ##لو
# اولدوزلو ناخێش اولام., confidence: 0.0666143149137497
# ==================================================
# Input:  اینسانلار قورخودان وه دۆنیا اۆزهرینه گلن فلاکتلری گؤزلهمکدن هوشونو ایتیرهجک ، چۆنکی سما جیسیملری لرزهیه گلهجک .
# Masked Word:  گؤزلهمکدن
# Predicted Word:  ،
# اینسانلار قورخودان وه دۆنیا اۆزهرینه گلن فلاکتلری ، هوشونو ایتیرهجک ، چۆنکی سما جیسیملری لرزهیه گلهجک., confidence: 0.1475125253200531
# Predicted Word:  ایله
# اینسانلار قورخودان وه دۆنیا اۆزهرینه گلن فلاکتلری ایله هوشونو ایتیرهجک ، چۆنکی سما جیسیملری لرزهیه گلهجک., confidence: 0.0713687315583229
# Predicted Word:  اوز
# اینسانلار قورخودان وه دۆنیا اۆزهرینه گلن فلاکتلری اوز هوشونو ایتیرهجک ، چۆنکی سما جیسیملری لرزهیه گلهجک., confidence: 0.06880621612071991
# Predicted Word:  وه
# اینسانلار قورخودان وه دۆنیا اۆزهرینه گلن فلاکتلری وه هوشونو ایتیرهجک ، چۆنکی سما جیسیملری لرزهیه گلهجک., confidence: 0.06410851329565048
# Predicted Word:  ده
# اینسانلار قورخودان وه دۆنیا اۆزهرینه گلن فلاکتلری ده هوشونو ایتیرهجک ، چۆنکی سما جیسیملری لرزهیه گلهجک., confidence: 0.06209564208984375
# ==================================================
# Input:  آخشام ائوده صاحب اولاجاغێن شئی بودور .
# Masked Word:  شئی
# Predicted Word:  ##ێ
# اخشام ايوده صاحب اولاجاغێنێ بودور., confidence: 0.19323892891407013
# Predicted Word:  بیری
# اخشام ايوده صاحب اولاجاغێن بیری بودور., confidence: 0.09132619202136993
# Predicted Word:  ##ێز
# اخشام ايوده صاحب اولاجاغێنێز بودور., confidence: 0.0458696074783802
# Predicted Word:  دا
# اخشام ايوده صاحب اولاجاغێن دا بودور., confidence: 0.043948523700237274
# Predicted Word:  سونرا
# اخشام ايوده صاحب اولاجاغێن سونرا بودور., confidence: 0.022462982684373856
# ==================================================
# Input:  زهمتکشلر کندن حاجێ آتاکیشیلر گئتسین حاجێ آتاکیشینین دوداقلارێ تیترهدی .
# Masked Word:  .
# Predicted Word:  .
# زهمتکشلر کندن حاجێ اتاکیشیلر گيتسین حاجێ اتاکیشینین دوداقلارێ تیترهدی., confidence: 0.9978756904602051
# Predicted Word:  !
# زهمتکشلر کندن حاجێ اتاکیشیلر گيتسین حاجێ اتاکیشینین دوداقلارێ تیترهدی!, confidence: 0.0016310407081618905
# Predicted Word:  ؟
# زهمتکشلر کندن حاجێ اتاکیشیلر گيتسین حاجێ اتاکیشینین دوداقلارێ تیترهدی ؟, confidence: 0.00046136986929923296
# Predicted Word:  ##سین
# زهمتکشلر کندن حاجێ اتاکیشیلر گيتسین حاجێ اتاکیشینین دوداقلارێ تیترهدیسین, confidence: 1.79307718894961e-07
# Predicted Word:  یيت
# زهمتکشلر کندن حاجێ اتاکیشیلر گيتسین حاجێ اتاکیشینین دوداقلارێ تیترهدی یيت, confidence: 1.5034305533845327e-07
# ==================================================
# Input:  آمما اونو مدرن شعرین ان قاباقجیل و اؤزوده جیددی‌لریندن بیری حئساب ائدیرلر .
# Masked Word:  اؤزوده
# Predicted Word:  اونون
# امما اونو مدرن شعرین ان قاباقجیل و اونون جیددیلریندن بیری حيساب ايدیرلر., confidence: 0.06747632473707199
# Predicted Word:  یا
# امما اونو مدرن شعرین ان قاباقجیل و یا جیددیلریندن بیری حيساب ايدیرلر., confidence: 0.039852872490882874
# Predicted Word:  اوز
# امما اونو مدرن شعرین ان قاباقجیل و اوز جیددیلریندن بیری حيساب ايدیرلر., confidence: 0.030918480828404427
# Predicted Word:  بوتون
# امما اونو مدرن شعرین ان قاباقجیل و بوتون جیددیلریندن بیری حيساب ايدیرلر., confidence: 0.02460061013698578
# Predicted Word:  اونلارین
# امما اونو مدرن شعرین ان قاباقجیل و اونلارین جیددیلریندن بیری حيساب ايدیرلر., confidence: 0.02314266562461853
# ==================================================
# Input:  آغێلسێز هرهکتلر ائدن .
# Masked Word:  ائدن
# Predicted Word:  وار
# اغێلسێز هرهکتلر وار., confidence: 0.060448043048381805
# Predicted Word:  ایدی
# اغێلسێز هرهکتلر ایدی., confidence: 0.03406625986099243
# Predicted Word:  واردێر
# اغێلسێز هرهکتلر واردێر., confidence: 0.033944062888622284
# Predicted Word:  اولور
# اغێلسێز هرهکتلر اولور., confidence: 0.03248598054051399
# Predicted Word:  ايدیر
# اغێلسێز هرهکتلر ايدیر., confidence: 0.029553504660725594
# ==================================================
# Input:  خورقع دئیه مێزێل دانێردێ .
# Masked Word:  مێزێل
# Predicted Word:  قولاق
# خورقع ديیه قولاق دانێردێ., confidence: 0.02784384973347187
# Predicted Word:  قێز
# خورقع ديیه قێز دانێردێ., confidence: 0.020307064056396484
# Predicted Word:  اونو
# خورقع ديیه اونو دانێردێ., confidence: 0.018643252551555634
# Predicted Word:  جان
# خورقع ديیه جان دانێردێ., confidence: 0.01472832728177309
# Predicted Word:  باشێنێ
# خورقع ديیه باشێنێ دانێردێ., confidence: 0.013786912895739079
# ==================================================
# Input:  داوود ایانلاریندان بیر نئچهسینی خانونون آتاسێ اۆچۆن باشساغلیغی وئرمهیه گؤندردی .
# Masked Word:  داوود
# Predicted Word:  اونون
# اونون ایانلاریندان بیر نيچهسینی خانونون اتاسێ اۆچۆن باشساغلیغی ويرمهیه گوندردی., confidence: 0.06397748738527298
# Predicted Word:  اونلارێن
# اونلارێن ایانلاریندان بیر نيچهسینی خانونون اتاسێ اۆچۆن باشساغلیغی ويرمهیه گوندردی., confidence: 0.04207586869597435
# Predicted Word:  بو
# بو ایانلاریندان بیر نيچهسینی خانونون اتاسێ اۆچۆن باشساغلیغی ويرمهیه گوندردی., confidence: 0.032874688506126404
# Predicted Word:  سونرا
# سونرا ایانلاریندان بیر نيچهسینی خانونون اتاسێ اۆچۆن باشساغلیغی ويرمهیه گوندردی., confidence: 0.030929643660783768
# Predicted Word:  او
# او ایانلاریندان بیر نيچهسینی خانونون اتاسێ اۆچۆن باشساغلیغی ويرمهیه گوندردی., confidence: 0.02953258901834488
# ==================================================
# Input:  سیاسی فعاللێق سیاستین مقصوداویغونلوغونینینینیدون اینیکآسیدیر .
# Masked Word:  سیاسی
# Predicted Word:  غیری
# غیری فعاللێق سیاستین مقصوداویغونلوغونینینینیدون اینیکاسیدیر., confidence: 0.04225942865014076
# Predicted Word:  اذربایجانین
# اذربایجانین فعاللێق سیاستین مقصوداویغونلوغونینینینیدون اینیکاسیدیر., confidence: 0.04200372472405434
# Predicted Word:  اقتصادی
# اقتصادی فعاللێق سیاستین مقصوداویغونلوغونینینینیدون اینیکاسیدیر., confidence: 0.03556588664650917
# Predicted Word:  میللی
# میللی فعاللێق سیاستین مقصوداویغونلوغونینینینیدون اینیکاسیدیر., confidence: 0.03471875190734863
# Predicted Word:  اذربایجاندا
# اذربایجاندا فعاللێق سیاستین مقصوداویغونلوغونینینینیدون اینیکاسیدیر., confidence: 0.03420804440975189
# ==================================================
# Input:  بئلهلیکله ، آذربایجان یئنی مرحلهیه قدم قویاجاقدیر .
# Masked Word:  .
# Predicted Word:  .
# بيلهلیکله ، اذربایجان یينی مرحلهیه قدم قویاجاقدیر., confidence: 0.9956719875335693
# Predicted Word:  ؟
# بيلهلیکله ، اذربایجان یينی مرحلهیه قدم قویاجاقدیر ؟, confidence: 0.0029018372297286987
# Predicted Word:  !
# بيلهلیکله ، اذربایجان یينی مرحلهیه قدم قویاجاقدیر!, confidence: 0.0013791214441880584
# Predicted Word:  ،
# بيلهلیکله ، اذربایجان یينی مرحلهیه قدم قویاجاقدیر ،, confidence: 4.918757099403592e-07
# Predicted Word:  ##سین
# بيلهلیکله ، اذربایجان یينی مرحلهیه قدم قویاجاقدیرسین, confidence: 3.431194386394054e-07
# ==================================================
# Input:  داغ سویوندان سامووار قایناداردی .
# Masked Word:  سامووار
# Predicted Word:  بیرینی
# داغ سویوندان بیرینی قایناداردی., confidence: 0.06111573427915573
# Predicted Word:  بیرینه
# داغ سویوندان بیرینه قایناداردی., confidence: 0.01972135528922081
# Predicted Word:  بیر
# داغ سویوندان بیر قایناداردی., confidence: 0.018344268202781677
# Predicted Word:  یوخاری
# داغ سویوندان یوخاری قایناداردی., confidence: 0.016783714294433594
# Predicted Word:  برک
# داغ سویوندان برک قایناداردی., confidence: 0.01658400148153305
# ==================================================
# Input:  تطبیقی خاراکتئر داشیییردی .
# Masked Word:  خاراکتئر
# Predicted Word:  خاراکتير
# تطبیقی خاراکتير داشیییردی., confidence: 0.06057670712471008
# Predicted Word:  شرایت
# تطبیقی شرایت داشیییردی., confidence: 0.024756742641329765
# Predicted Word:  گينیش
# تطبیقی گينیش داشیییردی., confidence: 0.019104601815342903
# Predicted Word:  ##نی
# تطبیقینی داشیییردی., confidence: 0.018484508618712425
# Predicted Word:  دقت
# تطبیقی دقت داشیییردی., confidence: 0.018403703346848488
# ==================================================
# Input:  خبری ائشیدنلر قاراباغ کانالێنا طرف آخێشێردێ .
# Masked Word:  کانالێنا
# Predicted Word:  ##ا
# خبری ايشیدنلر قاراباغا طرف اخێشێردێ., confidence: 0.6917564272880554
# Predicted Word:  ##ێنا
# خبری ايشیدنلر قاراباغێنا طرف اخێشێردێ., confidence: 0.04417087510228157
# Predicted Word:  ##یا
# خبری ايشیدنلر قاراباغیا طرف اخێشێردێ., confidence: 0.01775108091533184
# Predicted Word:  اونا
# خبری ايشیدنلر قاراباغ اونا طرف اخێشێردێ., confidence: 0.014715799130499363
# Predicted Word:  ##لارا
# خبری ايشیدنلر قاراباغلارا طرف اخێشێردێ., confidence: 0.012327892705798149
# ==================================================
# Input:  وئرسآلدا ملتلر لێقاسی تاسیس اولوندو .
# Masked Word:  تاسیس
# Predicted Word:  قبول
# ويرسالدا ملتلر لێقاسی قبول اولوندو., confidence: 0.09389135241508484
# Predicted Word:  قيید
# ويرسالدا ملتلر لێقاسی قيید اولوندو., confidence: 0.08510785549879074
# Predicted Word:  تعیین
# ويرسالدا ملتلر لێقاسی تعیین اولوندو., confidence: 0.046087369322776794
# Predicted Word:  تشکیل
# ويرسالدا ملتلر لێقاسی تشکیل اولوندو., confidence: 0.04171790927648544
# Predicted Word:  درج
# ويرسالدا ملتلر لێقاسی درج اولوندو., confidence: 0.03786585107445717
# ==================================================
# Input:  مالایزیا داخل ایدی .
# Masked Word:  مالایزیا
# Predicted Word:  اونا
# اونا داخل ایدی., confidence: 0.014504932798445225
# Predicted Word:  ایچری
# ایچری داخل ایدی., confidence: 0.013099041767418385
# Predicted Word:  نفر
# نفر داخل ایدی., confidence: 0.01125742495059967
# Predicted Word:  سونرا
# سونرا داخل ایدی., confidence: 0.009719956666231155
# Predicted Word:  اونلار
# اونلار داخل ایدی., confidence: 0.006850455887615681
# ==================================================
# Input:  آغلاشمادا آغێ دئییب آغلاردێ .
# Masked Word:  آغێ
# Predicted Word:  ##ن
# اغلاشمادان ديییب اغلاردێ., confidence: 0.0534156858921051
# Predicted Word:  ##م
# اغلاشمادام ديییب اغلاردێ., confidence: 0.026379462331533432
# Predicted Word:  بيله
# اغلاشمادا بيله ديییب اغلاردێ., confidence: 0.020677456632256508
# Predicted Word:  ایسه
# اغلاشمادا ایسه ديییب اغلاردێ., confidence: 0.013007508590817451
# Predicted Word:  ##ز
# اغلاشماداز ديییب اغلاردێ., confidence: 0.01020011492073536
# ==================================================
# Input:  یادا یاریسی ، دوغمایا هامێسێ آتالار دئمیشکن .
# Masked Word:  دوغمایا
# Predicted Word:  اونلارێن
# یادا یاریسی ، اونلارێن هامێسێ اتالار ديمیشکن., confidence: 0.3203675150871277
# Predicted Word:  بونلارێن
# یادا یاریسی ، بونلارێن هامێسێ اتالار ديمیشکن., confidence: 0.14502225816249847
# Predicted Word:  بونلار
# یادا یاریسی ، بونلار هامێسێ اتالار ديمیشکن., confidence: 0.06674546003341675
# Predicted Word:  اونلار
# یادا یاریسی ، اونلار هامێسێ اتالار ديمیشکن., confidence: 0.021559089422225952
# Predicted Word:  اونون
# یادا یاریسی ، اونون هامێسێ اتالار ديمیشکن., confidence: 0.015581431798636913
# ==================================================
# Input:  هرهسی آغزێنێ بیر یانا توتار .
# Masked Word:  یانا
# Predicted Word:  یيره
# هرهسی اغزێنێ بیر یيره توتار., confidence: 0.06477200239896774
# Predicted Word:  یيرده
# هرهسی اغزێنێ بیر یيرده توتار., confidence: 0.05380619317293167
# Predicted Word:  بیرینه
# هرهسی اغزێنێ بیر بیرینه توتار., confidence: 0.04272989556193352
# Predicted Word:  شيی
# هرهسی اغزێنێ بیر شيی توتار., confidence: 0.02731924131512642
# Predicted Word:  طرفه
# هرهسی اغزێنێ بیر طرفه توتار., confidence: 0.027126112952828407
# ==================================================
# Input:  ساوالانێن قارێ کیمی تئللرین وار .
# Masked Word:  .
# Predicted Word:  .
# ساوالانێن قارێ کیمی تيللرین وار., confidence: 0.9991581439971924
# Predicted Word:  !
# ساوالانێن قارێ کیمی تيللرین وار!, confidence: 0.0006937839789316058
# Predicted Word:  ؟
# ساوالانێن قارێ کیمی تيللرین وار ؟, confidence: 0.00012007014447590336
# Predicted Word:  ##اق
# ساوالانێن قارێ کیمی تيللرین واراق, confidence: 1.0348900758572199e-07
# Predicted Word:  ##ێ
# ساوالانێن قارێ کیمی تيللرین وارێ, confidence: 9.65405888564419e-08
# ==================================================
# Input:  ینجی ایللرین اوللرینده باکیدا یئنیجه آچیلمیش آزاد تنقید و تبلیغ تئاتریندا آکتیور ایشله‌ییب .
# Masked Word:  تنقید
# Predicted Word:  ##لیق
# ینجی ایللرین اوللرینده باکیدا یينیجه اچیلمیش ازادلیق و تبلیغ تياتریندا اکتیور ایشلهییب., confidence: 0.08626449853181839
# Predicted Word:  اولوب
# ینجی ایللرین اوللرینده باکیدا یينیجه اچیلمیش ازاد اولوب و تبلیغ تياتریندا اکتیور ایشلهییب., confidence: 0.04475947469472885
# Predicted Word:  ##لر
# ینجی ایللرین اوللرینده باکیدا یينیجه اچیلمیش ازادلر و تبلیغ تياتریندا اکتیور ایشلهییب., confidence: 0.02934604324400425
# Predicted Word:  ##ی
# ینجی ایللرین اوللرینده باکیدا یينیجه اچیلمیش ازادی و تبلیغ تياتریندا اکتیور ایشلهییب., confidence: 0.02614348568022251
# Predicted Word:  ايدیلیب
# ینجی ایللرین اوللرینده باکیدا یينیجه اچیلمیش ازاد ايدیلیب و تبلیغ تياتریندا اکتیور ایشلهییب., confidence: 0.022036239504814148
# ==================================================
# Input:  خارجدن یئمک گتیریلمهسینه امکان وئرمیردیلر .
# Masked Word:  .
# Predicted Word:  .
# خارجدن یيمک گتیریلمهسینه امکان ويرمیردیلر., confidence: 0.9997395873069763
# Predicted Word:  ؟
# خارجدن یيمک گتیریلمهسینه امکان ويرمیردیلر ؟, confidence: 0.00012124601926188916
# Predicted Word:  !
# خارجدن یيمک گتیریلمهسینه امکان ويرمیردیلر!, confidence: 0.00010716293763834983
# Predicted Word:  ##یک
# خارجدن یيمک گتیریلمهسینه امکان ويرمیردیلریک, confidence: 3.536272288329201e-07
# Predicted Word:  ،
# خارجدن یيمک گتیریلمهسینه امکان ويرمیردیلر ،, confidence: 1.5524669549904502e-07
# ==================================================
# Input:  اوْ خونه‌به‌خونه فوتبول کولوبونا گلندن اؤنجه ایستیقلال اهواز فوتبول کولوبوندا اوْینامیش‌دیر اوْینادیغی تیم‌لر .
# Masked Word:  .
# Predicted Word:  .
# او خونهبهخونه فوتبول کولوبونا گلندن اونجه ایستیقلال اهواز فوتبول کولوبوندا اوینامیشدیر اوینادیغی تیملر., confidence: 0.9923011064529419
# Predicted Word:  !
# او خونهبهخونه فوتبول کولوبونا گلندن اونجه ایستیقلال اهواز فوتبول کولوبوندا اوینامیشدیر اوینادیغی تیملر!, confidence: 0.005581342149525881
# Predicted Word:  ؟
# او خونهبهخونه فوتبول کولوبونا گلندن اونجه ایستیقلال اهواز فوتبول کولوبوندا اوینامیشدیر اوینادیغی تیملر ؟, confidence: 0.002036419929936528
# Predicted Word:  ،
# او خونهبهخونه فوتبول کولوبونا گلندن اونجه ایستیقلال اهواز فوتبول کولوبوندا اوینامیشدیر اوینادیغی تیملر ،, confidence: 7.350085979851428e-07
# Predicted Word:  ##اق
# او خونهبهخونه فوتبول کولوبونا گلندن اونجه ایستیقلال اهواز فوتبول کولوبوندا اوینامیشدیر اوینادیغی تیملراق, confidence: 4.788291789736832e-07
# ==================================================
# Input:  اونونلا هامێ حسابلاشێر .
# Masked Word:  هامێ
# Predicted Word:  باغلێ
# اونونلا باغلێ حسابلاشێر., confidence: 0.07488581538200378
# Predicted Word:  برابر
# اونونلا برابر حسابلاشێر., confidence: 0.05334105342626572
# Predicted Word:  الاقدار
# اونونلا الاقدار حسابلاشێر., confidence: 0.0476166196167469
# Predicted Word:  بیرلیکده
# اونونلا بیرلیکده حسابلاشێر., confidence: 0.04491342976689339
# Predicted Word:  علاقه
# اونونلا علاقه حسابلاشێر., confidence: 0.024297703057527542
# ==================================================
# Input:  اینگیلیسجه ویکی‌پدیاسی‌نین ایشلدنلری طرفیندن یارانمیش ، مقاله‌سیندن گؤتورولوبدور قمینا شدلیشچه لهیستان‌دا بیر یاشاییش منطقه‌سی‌دیر کیلومتر موربع ساحه‌سی وار .
# Masked Word:  اینگیلیسجه
# Predicted Word:  اینگیلیسجه
# اینگیلیسجه ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور قمینا شدلیشچه لهیستاندا بیر یاشاییش منطقهسیدیر کیلومتر موربع ساحهسی وار., confidence: 0.999809205532074
# Predicted Word:  ایشلدنلری
# ایشلدنلری ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور قمینا شدلیشچه لهیستاندا بیر یاشاییش منطقهسیدیر کیلومتر موربع ساحهسی وار., confidence: 5.104305091663264e-05
# Predicted Word:  قمینا
# قمینا ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور قمینا شدلیشچه لهیستاندا بیر یاشاییش منطقهسیدیر کیلومتر موربع ساحهسی وار., confidence: 1.5447474652319215e-05
# Predicted Word:  طرفیندن
# طرفیندن ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور قمینا شدلیشچه لهیستاندا بیر یاشاییش منطقهسیدیر کیلومتر موربع ساحهسی وار., confidence: 1.286737278860528e-05
# Predicted Word:  مقالهسیندن
# مقالهسیندن ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور قمینا شدلیشچه لهیستاندا بیر یاشاییش منطقهسیدیر کیلومتر موربع ساحهسی وار., confidence: 8.593863640271593e-06
# ==================================================
# Input:  فرمئرلر اریزهلری دؤؤلت آقرار اینکیشاف مرکزلرینه تقدیم ائتمهلی وه یا ائکتینس ا داخل اولاراق مۆصابقده اشتراکلا باغلێ الکترون قایدادا قئیدییاتدان کئچمهلیدیر .
# Masked Word:  داخل
# Predicted Word:  اویغون
# فرميرلر اریزهلری دوولت اقرار اینکیشاف مرکزلرینه تقدیم ايتمهلی وه یا ايکتینس ا اویغون اولاراق مۆصابقده اشتراکلا باغلێ الکترون قایدادا قيیدییاتدان کيچمهلیدیر., confidence: 0.3255232274532318
# Predicted Word:  داخل
# فرميرلر اریزهلری دوولت اقرار اینکیشاف مرکزلرینه تقدیم ايتمهلی وه یا ايکتینس ا داخل اولاراق مۆصابقده اشتراکلا باغلێ الکترون قایدادا قيیدییاتدان کيچمهلیدیر., confidence: 0.09471911191940308
# Predicted Word:  جاواب
# فرميرلر اریزهلری دوولت اقرار اینکیشاف مرکزلرینه تقدیم ايتمهلی وه یا ايکتینس ا جاواب اولاراق مۆصابقده اشتراکلا باغلێ الکترون قایدادا قيیدییاتدان کيچمهلیدیر., confidence: 0.020798297598958015
# Predicted Word:  تابع
# فرميرلر اریزهلری دوولت اقرار اینکیشاف مرکزلرینه تقدیم ايتمهلی وه یا ايکتینس ا تابع اولاراق مۆصابقده اشتراکلا باغلێ الکترون قایدادا قيیدییاتدان کيچمهلیدیر., confidence: 0.014682146720588207
# Predicted Word:  الاقدار
# فرميرلر اریزهلری دوولت اقرار اینکیشاف مرکزلرینه تقدیم ايتمهلی وه یا ايکتینس ا الاقدار اولاراق مۆصابقده اشتراکلا باغلێ الکترون قایدادا قيیدییاتدان کيچمهلیدیر., confidence: 0.012048162519931793
# ==================================================
# Input:  سوعال من ائستونیادانام .
# Masked Word:  سوعال
# Predicted Word:  امما
# امما من ايستونیادانام., confidence: 0.10993767529726028
# Predicted Word:  ایندی
# ایندی من ايستونیادانام., confidence: 0.08280293643474579
# Predicted Word:  انجاق
# انجاق من ايستونیادانام., confidence: 0.06973863393068314
# Predicted Word:  لاکین
# لاکین من ايستونیادانام., confidence: 0.037908535450696945
# Predicted Word:  اخێ
# اخێ من ايستونیادانام., confidence: 0.033054135739803314
# ==================================================
# Input:  بیزیم بو میللی دیرچهلیش ، میللی اویانیش ، میللی اؤزونوتانیما پروسئسینده قوبوستان اێن رولو چوخ بؤیوک اولوبدور .
# Masked Word:  ،
# Predicted Word:  ،
# بیزیم بو میللی دیرچهلیش ، میللی اویانیش ، میللی اوزونوتانیما پروسيسینده قوبوستان اێن رولو چوخ بویوک اولوبدور., confidence: 0.2235550880432129
# Predicted Word:  وه
# بیزیم بو میللی دیرچهلیش وه میللی اویانیش ، میللی اوزونوتانیما پروسيسینده قوبوستان اێن رولو چوخ بویوک اولوبدور., confidence: 0.06658308207988739
# Predicted Word:  ##لر
# بیزیم بو میللی دیرچهلیشلر میللی اویانیش ، میللی اوزونوتانیما پروسيسینده قوبوستان اێن رولو چوخ بویوک اولوبدور., confidence: 0.035228509455919266
# Predicted Word:  ##له
# بیزیم بو میللی دیرچهلیشله میللی اویانیش ، میللی اوزونوتانیما پروسيسینده قوبوستان اێن رولو چوخ بویوک اولوبدور., confidence: 0.024394920095801353
# Predicted Word:  کیمی
# بیزیم بو میللی دیرچهلیش کیمی میللی اویانیش ، میللی اوزونوتانیما پروسيسینده قوبوستان اێن رولو چوخ بویوک اولوبدور., confidence: 0.0226823091506958
# ==================================================
# Input:  آللاه طعالا ایسته یینجه هر شئی اولوردو .
# Masked Word:  شئی
# Predicted Word:  شيی
# اللاه طعالا ایسته یینجه هر شيی اولوردو., confidence: 0.31655243039131165
# Predicted Word:  شيیی
# اللاه طعالا ایسته یینجه هر شيیی اولوردو., confidence: 0.1812797486782074
# Predicted Word:  کس
# اللاه طعالا ایسته یینجه هر کس اولوردو., confidence: 0.0927794799208641
# Predicted Word:  یيرده
# اللاه طعالا ایسته یینجه هر یيرده اولوردو., confidence: 0.03709524869918823
# Predicted Word:  زامان
# اللاه طعالا ایسته یینجه هر زامان اولوردو., confidence: 0.031946733593940735
# ==================================================
# Input:  چوخ واخت آتماقول چوخا آدلانێردێ .
# Masked Word:  آدلانێردێ
# Predicted Word:  بیلر
# چوخ واخت اتماقول چوخا بیلر., confidence: 0.10696905106306076
# Predicted Word:  گلیر
# چوخ واخت اتماقول چوخا گلیر., confidence: 0.04411463811993599
# Predicted Word:  بیلیر
# چوخ واخت اتماقول چوخا بیلیر., confidence: 0.043824005872011185
# Predicted Word:  بیلمیر
# چوخ واخت اتماقول چوخا بیلمیر., confidence: 0.03906764090061188
# Predicted Word:  قدر
# چوخ واخت اتماقول چوخا قدر., confidence: 0.03816988319158554
# ==================================================
# Input:  اینگیلیسجه ویکی‌پدیاسی‌نین ایشلدنلری طرفیندن یارانمیش ، مقاله‌سیندن گؤتورولوبدور سنت جورجز ، دلاویر آمریکا اؤلکه‌سینده بیر یاشاییش منطقه‌سی‌دیر و دلاویر ایالتینده یئرلشیب .
# Masked Word:  سنت
# Predicted Word:  لیک
# اینگیلیسجه ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور لیک جورجز ، دلاویر امریکا اولکهسینده بیر یاشاییش منطقهسیدیر و دلاویر ایالتینده یيرلشیب., confidence: 0.02988983318209648
# Predicted Word:  وست
# اینگیلیسجه ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور وست جورجز ، دلاویر امریکا اولکهسینده بیر یاشاییش منطقهسیدیر و دلاویر ایالتینده یيرلشیب., confidence: 0.019134070724248886
# Predicted Word:  بر
# اینگیلیسجه ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور بر جورجز ، دلاویر امریکا اولکهسینده بیر یاشاییش منطقهسیدیر و دلاویر ایالتینده یيرلشیب., confidence: 0.017896031960844994
# Predicted Word:  نیو
# اینگیلیسجه ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور نیو جورجز ، دلاویر امریکا اولکهسینده بیر یاشاییش منطقهسیدیر و دلاویر ایالتینده یيرلشیب., confidence: 0.017709461972117424
# Predicted Word:  وی
# اینگیلیسجه ویکیپدیاسینین ایشلدنلری طرفیندن یارانمیش ، مقالهسیندن گوتورولوبدور وی جورجز ، دلاویر امریکا اولکهسینده بیر یاشاییش منطقهسیدیر و دلاویر ایالتینده یيرلشیب., confidence: 0.013750942423939705
# ==================================================
# Input:  آپا نێن ملوماتێنا گؤره ، مراسمده چێخێش ائدن نوریده آتشی تدقیقاتا ایل اول باشلادێغێنێ دئمیشدیر .
# Masked Word:  تدقیقاتا
# Predicted Word:  جی
# اپا نێن ملوماتێنا گوره ، مراسمده چێخێش ايدن نوریده اتشی جی ایل اول باشلادێغێنێ ديمیشدیر., confidence: 0.12893569469451904
# Predicted Word:  جۆ
# اپا نێن ملوماتێنا گوره ، مراسمده چێخێش ايدن نوریده اتشی جۆ ایل اول باشلادێغێنێ ديمیشدیر., confidence: 0.07114891707897186
# Predicted Word:  کيچن
# اپا نێن ملوماتێنا گوره ، مراسمده چێخێش ايدن نوریده اتشی کيچن ایل اول باشلادێغێنێ ديمیشدیر., confidence: 0.06663836538791656
# Predicted Word:  اوتن
# اپا نێن ملوماتێنا گوره ، مراسمده چێخێش ايدن نوریده اتشی اوتن ایل اول باشلادێغێنێ ديمیشدیر., confidence: 0.04911871999502182
# Predicted Word:  بو
# اپا نێن ملوماتێنا گوره ، مراسمده چێخێش ايدن نوریده اتشی بو ایل اول باشلادێغێنێ ديمیشدیر., confidence: 0.048334818333387375
# ==================================================
# Input:  مشهور هیند تمسیلی نظرده توتولور .
# Masked Word:  نظرده
# Predicted Word:  نظرده
# مشهور هیند تمسیلی نظرده توتولور., confidence: 0.9748491644859314
# Predicted Word:  ایله
# مشهور هیند تمسیلی ایله توتولور., confidence: 0.004144475795328617
# Predicted Word:  نظره
# مشهور هیند تمسیلی نظره توتولور., confidence: 0.0020963959395885468
# Predicted Word:  اتشه
# مشهور هیند تمسیلی اتشه توتولور., confidence: 0.001408388139680028
# Predicted Word:  قيیده
# مشهور هیند تمسیلی قيیده توتولور., confidence: 0.0012608971446752548
# ==================================================
# Input:  قدیملی یئنیلی تاریخه مئیدان اوخونوردو .
# Masked Word:  قدیملی
# Predicted Word:  یينی
# یينی یينیلی تاریخه ميیدان اوخونوردو., confidence: 0.0724998414516449
# Predicted Word:  چوخ
# چوخ یينیلی تاریخه ميیدان اوخونوردو., confidence: 0.04316001012921333
# Predicted Word:  داها
# داها یينیلی تاریخه ميیدان اوخونوردو., confidence: 0.038205862045288086
# Predicted Word:  بورادا
# بورادا یينیلی تاریخه ميیدان اوخونوردو., confidence: 0.023659251630306244
# Predicted Word:  ینی
# ینی یينیلی تاریخه ميیدان اوخونوردو., confidence: 0.022248471155762672
# ==================================================
# Input:  هره بو پروبلئمی نئجه گؤرورسه ، ائله فکرلر ایرهلی سۆرۆرلر .
# Masked Word:  پروبلئمی
# Predicted Word:  ایشی
# هره بو ایشی نيجه گورورسه ، ايله فکرلر ایرهلی سۆرۆرلر., confidence: 0.048850078135728836
# Predicted Word:  گۆن
# هره بو گۆن نيجه گورورسه ، ايله فکرلر ایرهلی سۆرۆرلر., confidence: 0.0392737090587616
# Predicted Word:  ،
# هره بو ، نيجه گورورسه ، ايله فکرلر ایرهلی سۆرۆرلر., confidence: 0.03529417887330055
# Predicted Word:  سوزلری
# هره بو سوزلری نيجه گورورسه ، ايله فکرلر ایرهلی سۆرۆرلر., confidence: 0.033441390842199326
# Predicted Word:  قدر
# هره بو قدر نيجه گورورسه ، ايله فکرلر ایرهلی سۆرۆرلر., confidence: 0.03284894675016403
# ==================================================
# Input:  ایشاینیزده اوغورلار آرزولاییرام .
# Masked Word:  .
# Predicted Word:  .
# ایشاینیزده اوغورلار ارزولاییرام., confidence: 0.9986560344696045
# Predicted Word:  !
# ایشاینیزده اوغورلار ارزولاییرام!, confidence: 0.0009907572530210018
# Predicted Word:  ؟
# ایشاینیزده اوغورلار ارزولاییرام ؟, confidence: 0.00031513700378127396
# Predicted Word:  ،
# ایشاینیزده اوغورلار ارزولاییرام ،, confidence: 2.432004464480997e-07
# Predicted Word:  ##ز
# ایشاینیزده اوغورلار ارزولاییرامز, confidence: 2.411877630947856e-07
# ==================================================
# Input:  باواریا بوسسلارێنا بو پلاندا مصلحتمی وئره بیلهرم .
# Masked Word:  مصلحتمی
# Predicted Word:  جاواب
# باواریا بوسسلارێنا بو پلاندا جاواب ويره بیلهرم., confidence: 0.26692888140678406
# Predicted Word:  باش
# باواریا بوسسلارێنا بو پلاندا باش ويره بیلهرم., confidence: 0.256831556558609
# Predicted Word:  اجازه
# باواریا بوسسلارێنا بو پلاندا اجازه ويره بیلهرم., confidence: 0.03056742064654827
# Predicted Word:  معلومات
# باواریا بوسسلارێنا بو پلاندا معلومات ويره بیلهرم., confidence: 0.024136584252119064
# Predicted Word:  یول
# باواریا بوسسلارێنا بو پلاندا یول ويره بیلهرم., confidence: 0.02100343257188797
# ==================================================
# Input:  دقتله اونا باخێردێ .
# Masked Word:  باخێردێ
# Predicted Word:  باخدێ
# دقتله اونا باخدێ., confidence: 0.16442473232746124
# Predicted Word:  باخێر
# دقتله اونا باخێر., confidence: 0.048511795699596405
# Predicted Word:  باخێردێ
# دقتله اونا باخێردێ., confidence: 0.0448605976998806
# Predicted Word:  ويردی
# دقتله اونا ويردی., confidence: 0.04406820610165596
# Predicted Word:  یاخینلاشدی
# دقتله اونا یاخینلاشدی., confidence: 0.042947109788656235
# ==================================================
# Input:  من سندن چوخ رازێیام .
# Masked Word:  چوخ
# Predicted Word:  چوخ
# من سندن چوخ رازێیام., confidence: 0.49987760186195374
# Predicted Word:  داها
# من سندن داها رازێیام., confidence: 0.04010552912950516
# Predicted Word:  یاخشی
# من سندن یاخشی رازێیام., confidence: 0.02497081644833088
# Predicted Word:  ارتێق
# من سندن ارتێق رازێیام., confidence: 0.02462206594645977
# Predicted Word:  بیر
# من سندن بیر رازێیام., confidence: 0.01764790527522564
# ==================================================
# Input:  سونراسێ آللاه کریمدی .
# Masked Word:  کریمدی
# Predicted Word:  ##دێر
# سونراسێ اللاهدێر., confidence: 0.22987604141235352
# Predicted Word:  ويردی
# سونراسێ اللاه ويردی., confidence: 0.03631531447172165
# Predicted Word:  ایدی
# سونراسێ اللاه ایدی., confidence: 0.033663518726825714
# Predicted Word:  بیلیر
# سونراسێ اللاه بیلیر., confidence: 0.02786649763584137
# Predicted Word:  وار
# سونراسێ اللاه وار., confidence: 0.023073073476552963
# ==================================================
# Input:  بدهبده ، بیر قلبهدهین سؤز ده ائشیدیب ائلهسه ، دئیر ، اوشاقلارێ قێر ساققێز اولوب یاخاسیندان ال جکمهدیکلری اۆجۆن گلمهلی اولوب ، یوخسا ائله بیلمهسینلر ، کیمینسه دردیندن اؤلوب ائلهین وارمێش .
# Masked Word:  ساققێز
# Predicted Word:  ##ێق
# بدهبده ، بیر قلبهدهین سوز ده ايشیدیب ايلهسه ، ديیر ، اوشاقلارێ قێرێق اولوب یاخاسیندان ال جکمهدیکلری اۆجۆن گلمهلی اولوب ، یوخسا ايله بیلمهسینلر ، کیمینسه دردیندن اولوب ايلهین وارمێش., confidence: 0.0693185105919838
# Predicted Word:  ##ێب
# بدهبده ، بیر قلبهدهین سوز ده ايشیدیب ايلهسه ، ديیر ، اوشاقلارێ قێرێب اولوب یاخاسیندان ال جکمهدیکلری اۆجۆن گلمهلی اولوب ، یوخسا ايله بیلمهسینلر ، کیمینسه دردیندن اولوب ايلهین وارمێش., confidence: 0.05918392539024353
# Predicted Word:  ##ما
# بدهبده ، بیر قلبهدهین سوز ده ايشیدیب ايلهسه ، ديیر ، اوشاقلارێ قێرما اولوب یاخاسیندان ال جکمهدیکلری اۆجۆن گلمهلی اولوب ، یوخسا ايله بیلمهسینلر ، کیمینسه دردیندن اولوب ايلهین وارمێش., confidence: 0.05647267401218414
# Predicted Word:  ##ماق
# بدهبده ، بیر قلبهدهین سوز ده ايشیدیب ايلهسه ، ديیر ، اوشاقلارێ قێرماق اولوب یاخاسیندان ال جکمهدیکلری اۆجۆن گلمهلی اولوب ، یوخسا ايله بیلمهسینلر ، کیمینسه دردیندن اولوب ايلهین وارمێش., confidence: 0.0536508783698082
# Predicted Word:  ##ێلان
# بدهبده ، بیر قلبهدهین سوز ده ايشیدیب ايلهسه ، ديیر ، اوشاقلارێ قێرێلان اولوب یاخاسیندان ال جکمهدیکلری اۆجۆن گلمهلی اولوب ، یوخسا ايله بیلمهسینلر ، کیمینسه دردیندن اولوب ايلهین وارمێش., confidence: 0.03566049039363861
# ==================================================
# Input:  چۆنکی قصاص منیمدیر ، اوهزینی من وئرهجهیهم وه یئنه ده رب اؤز خالقێنێ مۆحاکمه ائدهجک دئینی تانیییریق .
# Masked Word:  وئرهجهیهم
# Predicted Word:  بیلیرم
# چۆنکی قصاص منیمدیر ، اوهزینی من بیلیرم وه یينه ده رب اوز خالقێنێ مۆحاکمه ايدهجک ديینی تانیییریق., confidence: 0.12178482860326767
# Predicted Word:  ایستهییرم
# چۆنکی قصاص منیمدیر ، اوهزینی من ایستهییرم وه یينه ده رب اوز خالقێنێ مۆحاکمه ايدهجک ديینی تانیییریق., confidence: 0.0397002138197422
# Predicted Word:  ایستهمیرم
# چۆنکی قصاص منیمدیر ، اوهزینی من ایستهمیرم وه یينه ده رب اوز خالقێنێ مۆحاکمه ايدهجک ديینی تانیییریق., confidence: 0.03536881133913994
# Predicted Word:  ايدهجهیم
# چۆنکی قصاص منیمدیر ، اوهزینی من ايدهجهیم وه یينه ده رب اوز خالقێنێ مۆحاکمه ايدهجک ديینی تانیییریق., confidence: 0.02804524265229702
# Predicted Word:  ديییرم
# چۆنکی قصاص منیمدیر ، اوهزینی من ديییرم وه یينه ده رب اوز خالقێنێ مۆحاکمه ايدهجک ديینی تانیییریق., confidence: 0.025857552886009216
# ==================================================
# Input:  آز آپا یا استنادن بیلدیریر کی ، بو بارهده روبئرت کوخ ایناستیتوتو معلومات یاییب .
# Masked Word:  معلومات
# Predicted Word:  معلومات
# از اپا یا استنادن بیلدیریر کی ، بو بارهده روبيرت کوخ ایناستیتوتو معلومات یاییب., confidence: 0.5030180811882019
# Predicted Word:  خبر
# از اپا یا استنادن بیلدیریر کی ، بو بارهده روبيرت کوخ ایناستیتوتو خبر یاییب., confidence: 0.08819713443517685
# Predicted Word:  اچیقلاما
# از اپا یا استنادن بیلدیریر کی ، بو بارهده روبيرت کوخ ایناستیتوتو اچیقلاما یاییب., confidence: 0.055474039167165756
# Predicted Word:  باش
# از اپا یا استنادن بیلدیریر کی ، بو بارهده روبيرت کوخ ایناستیتوتو باش یاییب., confidence: 0.044418103992938995
# Predicted Word:  جاواب
# از اپا یا استنادن بیلدیریر کی ، بو بارهده روبيرت کوخ ایناستیتوتو جاواب یاییب., confidence: 0.020684879273176193
# ==================================================
# Input:  اؤکسوز آدلی آتینا مینیب دوققوز دؤیوشجونو سونگوله دی .
# Masked Word:  دؤیوشجونو
# Predicted Word:  ،
# اوکسوز ادلی اتینا مینیب دوققوز ، سونگوله دی., confidence: 0.061269912868738174
# Predicted Word:  ##ون
# اوکسوز ادلی اتینا مینیب دوققوزون سونگوله دی., confidence: 0.02353092096745968
# Predicted Word:  ##و
# اوکسوز ادلی اتینا مینیب دوققوزو سونگوله دی., confidence: 0.021274205297231674
# Predicted Word:  ##ا
# اوکسوز ادلی اتینا مینیب دوققوزا سونگوله دی., confidence: 0.015634698793292046
# Predicted Word:  ایل
# اوکسوز ادلی اتینا مینیب دوققوز ایل سونگوله دی., confidence: 0.014783675782382488
# ==================================================
# Input:  بئینالخالق قێرمێزێ خاچ جمیتی واسطهسی ایله اونلارێن قوهوملارێ ایله الاقهلرینی تشکیل ائدیر .
# Masked Word:  تشکیل
# Predicted Word:  اهاته
# بيینالخالق قێرمێزێ خاچ جمیتی واسطهسی ایله اونلارێن قوهوملارێ ایله الاقهلرینی اهاته ايدیر., confidence: 0.16991528868675232
# Predicted Word:  تمین
# بيینالخالق قێرمێزێ خاچ جمیتی واسطهسی ایله اونلارێن قوهوملارێ ایله الاقهلرینی تمین ايدیر., confidence: 0.11613202095031738
# Predicted Word:  تشکیل
# بيینالخالق قێرمێزێ خاچ جمیتی واسطهسی ایله اونلارێن قوهوملارێ ایله الاقهلرینی تشکیل ايدیر., confidence: 0.08877358585596085
# Predicted Word:  افاده
# بيینالخالق قێرمێزێ خاچ جمیتی واسطهسی ایله اونلارێن قوهوملارێ ایله الاقهلرینی افاده ايدیر., confidence: 0.054084643721580505
# Predicted Word:  انکشاف
# بيینالخالق قێرمێزێ خاچ جمیتی واسطهسی ایله اونلارێن قوهوملارێ ایله الاقهلرینی انکشاف ايدیر., confidence: 0.03242528438568115
# ==================================================
# Input:  جنایت مسولیتینه جلب ائدیلمیش شخصلردن .
# Masked Word:  ائدیلمیش
# Predicted Word:  ايدن
# جنایت مسولیتینه جلب ايدن شخصلردن., confidence: 0.2879493832588196
# Predicted Word:  اولونان
# جنایت مسولیتینه جلب اولونان شخصلردن., confidence: 0.14975261688232422
# Predicted Word:  اولونموش
# جنایت مسولیتینه جلب اولونموش شخصلردن., confidence: 0.14291688799858093
# Predicted Word:  ايدیلمیش
# جنایت مسولیتینه جلب ايدیلمیش شخصلردن., confidence: 0.12922342121601105
# Predicted Word:  ايدیلن
# جنایت مسولیتینه جلب ايدیلن شخصلردن., confidence: 0.10421915352344513
# ==================================================
# Input:  قوبکین روسیه اؤلکه‌سینده یئر آلان بیر شهردیر و بیلقاراد اوبلاستینده یئرلشیب .
# Masked Word:  شهردیر
# Predicted Word:  شهردیر
# قوبکین روسیه اولکهسینده یير الان بیر شهردیر و بیلقاراد اوبلاستینده یيرلشیب., confidence: 0.9989120960235596
# Predicted Word:  فوتبالیست
# قوبکین روسیه اولکهسینده یير الان بیر فوتبالیست و بیلقاراد اوبلاستینده یيرلشیب., confidence: 0.00021780219685751945
# Predicted Word:  یاشاییش
# قوبکین روسیه اولکهسینده یير الان بیر یاشاییش و بیلقاراد اوبلاستینده یيرلشیب., confidence: 0.00018330466991756111
# Predicted Word:  کومون
# قوبکین روسیه اولکهسینده یير الان بیر کومون و بیلقاراد اوبلاستینده یيرلشیب., confidence: 8.566331234760582e-05
# Predicted Word:  منطقهسیدیر
# قوبکین روسیه اولکهسینده یير الان بیر منطقهسیدیر و بیلقاراد اوبلاستینده یيرلشیب., confidence: 8.101896673906595e-05
# ==================================================
# Input:  اینگیلیسیجه ویکی‌پدیا علی‌اصغر مدیرروستا ایرانلی فۇتبولچو .
# Masked Word:  اینگیلیسیجه
# Predicted Word:  اینگیلیسیجه
# اینگیلیسیجه ویکیپدیا علیاصغر مدیرروستا ایرانلی فۇتبولچو., confidence: 0.9378573894500732
# Predicted Word:  در
# در ویکیپدیا علیاصغر مدیرروستا ایرانلی فۇتبولچو., confidence: 0.002404875587671995
# Predicted Word:  ویکی
# ویکی ویکیپدیا علیاصغر مدیرروستا ایرانلی فۇتبولچو., confidence: 0.0020839376375079155
# Predicted Word:  از
# از ویکیپدیا علیاصغر مدیرروستا ایرانلی فۇتبولچو., confidence: 0.0017473314655944705
# Predicted Word:  میللی
# میللی ویکیپدیا علیاصغر مدیرروستا ایرانلی فۇتبولچو., confidence: 0.0015260770451277494
# ==================================================
# Input:  اونا دوعا ائدین غافر .
# Masked Word:  دوعا
# Predicted Word:  امل
# اونا امل ايدین غافر., confidence: 0.13788776099681854
# Predicted Word:  امر
# اونا امر ايدین غافر., confidence: 0.03142087161540985
# Predicted Word:  خیانت
# اونا خیانت ايدین غافر., confidence: 0.029196254909038544
# Predicted Word:  نفرت
# اونا نفرت ايدین غافر., confidence: 0.027536541223526
# Predicted Word:  قوللوق
# اونا قوللوق ايدین غافر., confidence: 0.017297795042395592
# ==================================================
# Input:  وایزی ایسه مجموعلر .
# Masked Word:  مجموعلر
# Predicted Word:  ایدی
# وایزی ایسه ایدی., confidence: 0.0361240915954113
# Predicted Word:  یوخدور
# وایزی ایسه یوخدور., confidence: 0.020956486463546753
# Predicted Word:  من
# وایزی ایسه من., confidence: 0.020683566108345985
# Predicted Word:  ديمکدیر
# وایزی ایسه ديمکدیر., confidence: 0.018717292696237564
# Predicted Word:  وار
# وایزی ایسه وار., confidence: 0.017014704644680023
# ==================================================
# Input:  بیزه لازێم اولان اساس فاکت بودور .
# Masked Word:  بیزه
# Predicted Word:  بونا
# بونا لازێم اولان اساس فاکت بودور., confidence: 0.21915292739868164
# Predicted Word:  اونا
# اونا لازێم اولان اساس فاکت بودور., confidence: 0.053760822862386703
# Predicted Word:  انجاق
# انجاق لازێم اولان اساس فاکت بودور., confidence: 0.05156664922833443
# Predicted Word:  بونو
# بونو لازێم اولان اساس فاکت بودور., confidence: 0.047351546585559845
# Predicted Word:  بیزه
# بیزه لازێم اولان اساس فاکت بودور., confidence: 0.04253382608294487
# ==================================================
# Input:  ائفراییم اوردوگاهیندان بؤلوکلرینه گؤره ساییلانلارین جمی نفر ایدی .
# Masked Word:  ائفراییم
# Predicted Word:  اذربایجان
# اذربایجان اوردوگاهیندان بولوکلرینه گوره ساییلانلارین جمی نفر ایدی., confidence: 0.06043705344200134
# Predicted Word:  اونون
# اونون اوردوگاهیندان بولوکلرینه گوره ساییلانلارین جمی نفر ایدی., confidence: 0.0572042278945446
# Predicted Word:  اونلارێن
# اونلارێن اوردوگاهیندان بولوکلرینه گوره ساییلانلارین جمی نفر ایدی., confidence: 0.03282945603132248
# Predicted Word:  اذربایجانین
# اذربایجانین اوردوگاهیندان بولوکلرینه گوره ساییلانلارین جمی نفر ایدی., confidence: 0.0268939770758152
# Predicted Word:  ایران
# ایران اوردوگاهیندان بولوکلرینه گوره ساییلانلارین جمی نفر ایدی., confidence: 0.024215396493673325
# ==================================================
# Input:  حکیم الیگئو نجف باکێلێدێر .
# Masked Word:  نجف
# Predicted Word:  ایسه
# حکیم الیگيو ایسه باکێلێدێر., confidence: 0.14237923920154572
# Predicted Word:  چوخ
# حکیم الیگيو چوخ باکێلێدێر., confidence: 0.041909247636795044
# Predicted Word:  ارتێق
# حکیم الیگيو ارتێق باکێلێدێر., confidence: 0.04019082710146904
# Predicted Word:  ادێ
# حکیم الیگيو ادێ باکێلێدێر., confidence: 0.017464768141508102
# Predicted Word:  ##ی
# حکیم الیگيوی باکێلێدێر., confidence: 0.016786079853773117
# ==================================================
# ...
# Input:  دیل بوغازا قویمازدی .
# Masked Word:  قویمازدی
# Predicted Word:  گلدی
# دیل بوغازا گلدی., confidence: 0.04935396835207939
# Predicted Word:  باخدێ
# دیل بوغازا باخدێ., confidence: 0.03534054756164551
# Predicted Word:  گلیر
# دیل بوغازا گلیر., confidence: 0.03499840572476387
# Predicted Word:  باخێردێ
# دیل بوغازا باخێردێ., confidence: 0.020632663741707802
# Predicted Word:  گيتدی
# دیل بوغازا گيتدی., confidence: 0.020014574751257896
# ==================================================
# Input:  چمن بیزیم اولوب .
# Masked Word:  .
# Predicted Word:  .
# چمن بیزیم اولوب., confidence: 0.9981512427330017
# Predicted Word:  !
# چمن بیزیم اولوب!, confidence: 0.0013267394388094544
# Predicted Word:  ؟
# چمن بیزیم اولوب ؟, confidence: 0.0004690205678343773
# Predicted Word:  هم
# چمن بیزیم اولوب هم, confidence: 2.3787410441400425e-07
# Predicted Word:  یيت
# چمن بیزیم اولوب یيت, confidence: 1.847648007924363e-07
# ==================================================
# Input:  من اونون قاتلینی آختارێرام .
# Masked Word:  من
# Predicted Word:  من
# من اونون قاتلینی اختارێرام., confidence: 0.7409120798110962
# Predicted Word:  امما
# امما اونون قاتلینی اختارێرام., confidence: 0.027348922565579414
# Predicted Word:  انجاق
# انجاق اونون قاتلینی اختارێرام., confidence: 0.013566707260906696
# Predicted Word:  ایندی
# ایندی اونون قاتلینی اختارێرام., confidence: 0.01224672980606556
# Predicted Word:  سنی
# سنی اونون قاتلینی اختارێرام., confidence: 0.010410161688923836
# ==================================================
# Input:  بیلمیرم هاچانسا ، اوز ایچیمده بیر حیس باش قالدیردی .
# Masked Word:  ،
# Predicted Word:  ،
# بیلمیرم هاچانسا ، اوز ایچیمده بیر حیس باش قالدیردی., confidence: 0.15113918483257294
# Predicted Word:  دا
# بیلمیرم هاچانسا دا اوز ایچیمده بیر حیس باش قالدیردی., confidence: 0.03736455738544464
# Predicted Word:  من
# بیلمیرم هاچانسا من اوز ایچیمده بیر حیس باش قالدیردی., confidence: 0.02841435745358467
# Predicted Word:  گوره
# بیلمیرم هاچانسا گوره اوز ایچیمده بیر حیس باش قالدیردی., confidence: 0.02772538736462593
# Predicted Word:  بیر
# بیلمیرم هاچانسا بیر اوز ایچیمده بیر حیس باش قالدیردی., confidence: 0.023925747722387314
# ==================================================
# Input:  لینا ایندی اونا باخێردێ .
# Masked Word:  باخێردێ
# Predicted Word:  باخدێ
# لینا ایندی اونا باخدێ., confidence: 0.11835899949073792
# Predicted Word:  باخێر
# لینا ایندی اونا باخێر., confidence: 0.06744522601366043
# Predicted Word:  ديدی
# لینا ایندی اونا ديدی., confidence: 0.06597635895013809
# Predicted Word:  باخێردێ
# لینا ایندی اونا باخێردێ., confidence: 0.03974417969584465
# Predicted Word:  یاخینلاشدی
# لینا ایندی اونا یاخینلاشدی., confidence: 0.03160135820508003
# ==================================================
# Input:  بیرده بو بئینالخالق تشکیلاتلار یا نه ایسه ائتسینلر ، یادا سادهجه سوسسونلار .
# Masked Word:  ایسه
# Predicted Word:  حساب
# بیرده بو بيینالخالق تشکیلاتلار یا نه حساب ايتسینلر ، یادا سادهجه سوسسونلار., confidence: 0.1205865889787674
# Predicted Word:  قبول
# بیرده بو بيینالخالق تشکیلاتلار یا نه قبول ايتسینلر ، یادا سادهجه سوسسونلار., confidence: 0.044759899377822876
# Predicted Word:  تقدیم
# بیرده بو بيینالخالق تشکیلاتلار یا نه تقدیم ايتسینلر ، یادا سادهجه سوسسونلار., confidence: 0.02813836745917797
# Predicted Word:  مۆراجعت
# بیرده بو بيینالخالق تشکیلاتلار یا نه مۆراجعت ايتسینلر ، یادا سادهجه سوسسونلار., confidence: 0.024475764483213425
# Predicted Word:  ##لیک
# بیرده بو بيینالخالق تشکیلاتلار یا نهلیک ايتسینلر ، یادا سادهجه سوسسونلار., confidence: 0.02159975841641426
# ==================================================
# Input:  اونلار سیزین سویونوزو کسیب .
# Masked Word:  .
# Predicted Word:  .
# اونلار سیزین سویونوزو کسیب., confidence: 0.994690477848053
# Predicted Word:  !
# اونلار سیزین سویونوزو کسیب!, confidence: 0.004235347267240286
# Predicted Word:  ؟
# اونلار سیزین سویونوزو کسیب ؟, confidence: 0.0009736561914905906
# Predicted Word:  ##نیز
# اونلار سیزین سویونوزو کسیبنیز, confidence: 8.430185403085488e-07
# Predicted Word:  ##ز
# اونلار سیزین سویونوزو کسیبز, confidence: 6.49838966637617e-07
# ==================================================
# Input:  یاغلی ودلرله تریفلهییر .
# Masked Word:  یاغلی
# Predicted Word:  اونو
# اونو ودلرله تریفلهییر., confidence: 0.024173779413104057
# Predicted Word:  اونلار
# اونلار ودلرله تریفلهییر., confidence: 0.017581842839717865
# Predicted Word:  ديیه
# ديیه ودلرله تریفلهییر., confidence: 0.015437901020050049
# Predicted Word:  اونلارێ
# اونلارێ ودلرله تریفلهییر., confidence: 0.015213510021567345
# Predicted Word:  منی
# منی ودلرله تریفلهییر., confidence: 0.012771353125572205
# ==================================================
# Input:  اؤلکهنین سهیه ناظرلیگی آئس ا یاخین یاشایان ساکینلره ایچمهلی سودان استفاده ائتمهمکله باغلێ خبردارلێق ائدیب .
# Masked Word:  ائتمهمکله
# Predicted Word:  ايتمهیه
# اولکهنین سهیه ناظرلیگی ايس ا یاخین یاشایان ساکینلره ایچمهلی سودان استفاده ايتمهیه باغلێ خبردارلێق ايدیب., confidence: 0.17511938512325287
# Predicted Word:  ایله
# اولکهنین سهیه ناظرلیگی ايس ا یاخین یاشایان ساکینلره ایچمهلی سودان استفاده ایله باغلێ خبردارلێق ايدیب., confidence: 0.15603956580162048
# Predicted Word:  ايتمکله
# اولکهنین سهیه ناظرلیگی ايس ا یاخین یاشایان ساکینلره ایچمهلی سودان استفاده ايتمکله باغلێ خبردارلێق ايدیب., confidence: 0.08399419486522675
# Predicted Word:  ##له
# اولکهنین سهیه ناظرلیگی ايس ا یاخین یاشایان ساکینلره ایچمهلی سودان استفادهله باغلێ خبردارلێق ايدیب., confidence: 0.07200215011835098
# Predicted Word:  ##لرله
# اولکهنین سهیه ناظرلیگی ايس ا یاخین یاشایان ساکینلره ایچمهلی سودان استفادهلرله باغلێ خبردارلێق ايدیب., confidence: 0.06780606508255005
# ==================================================
# Input:  روایت آشێغێن قایداسیدی .
# Masked Word:  روایت
# Predicted Word:  بیر
# بیر اشێغێن قایداسیدی., confidence: 0.02956460230052471
# Predicted Word:  امما
# امما اشێغێن قایداسیدی., confidence: 0.029152248054742813
# Predicted Word:  منیم
# منیم اشێغێن قایداسیدی., confidence: 0.02748776227235794
# Predicted Word:  اونون
# اونون اشێغێن قایداسیدی., confidence: 0.021311771124601364
# Predicted Word:  من
# من اشێغێن قایداسیدی., confidence: 0.015132153406739235
# ==================================================
# Input:  اونلاردان نفرینی محو ائدیب .
# Masked Word:  نفرینی
# Predicted Word:  بیری
# اونلاردان بیری محو ايدیب., confidence: 0.22465835511684418
# Predicted Word:  بیرینی
# اونلاردان بیرینی محو ايدیب., confidence: 0.14370690286159515
# Predicted Word:  سونرا
# اونلاردان سونرا محو ايدیب., confidence: 0.02730095013976097
# Predicted Word:  نفری
# اونلاردان نفری محو ايدیب., confidence: 0.016909033060073853
# Predicted Word:  چوخو
# اونلاردان چوخو محو ايدیب., confidence: 0.016343627125024796
# ==================================================
# Input:  اینگیلیسیجه ویکی‌پدیا سیامک کوروشی ایرانلی فۇتبولچو .
# Masked Word:  ویکی‌پدیا
# Predicted Word:  ویکی
# اینگیلیسیجه ویکی سیامک کوروشی ایرانلی فۇتبولچو., confidence: 0.3422674834728241
# Predicted Word:  پدیا
# اینگیلیسیجه پدیا سیامک کوروشی ایرانلی فۇتبولچو., confidence: 0.26159849762916565
# Predicted Word:  ویکیپدی
# اینگیلیسیجه ویکیپدی سیامک کوروشی ایرانلی فۇتبولچو., confidence: 0.1671322137117386
# Predicted Word:  اینگیلیسیجه
# اینگیلیسیجه اینگیلیسیجه سیامک کوروشی ایرانلی فۇتبولچو., confidence: 0.01200114842504263
# Predicted Word:  تیمی
# اینگیلیسیجه تیمی سیامک کوروشی ایرانلی فۇتبولچو., confidence: 0.007510639261454344
# ==================================================
# Input:  دئدی ساعات مونجا گلرسن .
# Masked Word:  گلرسن
# Predicted Word:  اولدو
# ديدی ساعات مونجا اولدو., confidence: 0.02945506013929844
# Predicted Word:  ایدی
# ديدی ساعات مونجا ایدی., confidence: 0.02894440107047558
# Predicted Word:  گلیر
# ديدی ساعات مونجا گلیر., confidence: 0.026669688522815704
# Predicted Word:  گلدی
# ديدی ساعات مونجا گلدی., confidence: 0.026185346767306328
# Predicted Word:  ديدی
# ديدی ساعات مونجا ديدی., confidence: 0.024891918525099754
# ==================================================
# Input:  آز سایتینین ملوماتێنا گؤره ، یێغمانین کاپیتانی ، قاراباغ اێن اۆزۆۆ رشاد سادیقوو زدهلی اولدوغو اۆچۆن میللینین مایین دن دک کئچیریلهجک تعلیم مشق توپلانێشێندا اشتراک ائتمهیهجک .
# Masked Word:  کئچیریلهجک
# Predicted Word:  یينی
# از سایتینین ملوماتێنا گوره ، یێغمانین کاپیتانی ، قاراباغ اێن اۆزۆۆ رشاد سادیقوو زدهلی اولدوغو اۆچۆن میللینین مایین دن دک یينی تعلیم مشق توپلانێشێندا اشتراک ايتمهیهجک., confidence: 0.056270990520715714
# Predicted Word:  ##ین
# از سایتینین ملوماتێنا گوره ، یێغمانین کاپیتانی ، قاراباغ اێن اۆزۆۆ رشاد سادیقوو زدهلی اولدوغو اۆچۆن میللینین مایین دن دکین تعلیم مشق توپلانێشێندا اشتراک ايتمهیهجک., confidence: 0.050685178488492966
# Predicted Word:  ##ی
# از سایتینین ملوماتێنا گوره ، یێغمانین کاپیتانی ، قاراباغ اێن اۆزۆۆ رشاد سادیقوو زدهلی اولدوغو اۆچۆن میللینین مایین دن دکی تعلیم مشق توپلانێشێندا اشتراک ايتمهیهجک., confidence: 0.047479014843702316
# Predicted Word:  حربی
# از سایتینین ملوماتێنا گوره ، یێغمانین کاپیتانی ، قاراباغ اێن اۆزۆۆ رشاد سادیقوو زدهلی اولدوغو اۆچۆن میللینین مایین دن دک حربی تعلیم مشق توپلانێشێندا اشتراک ايتمهیهجک., confidence: 0.03162096440792084
# Predicted Word:  ،
# از سایتینین ملوماتێنا گوره ، یێغمانین کاپیتانی ، قاراباغ اێن اۆزۆۆ رشاد سادیقوو زدهلی اولدوغو اۆچۆن میللینین مایین دن دک ، تعلیم مشق توپلانێشێندا اشتراک ايتمهیهجک., confidence: 0.020269982516765594
# ==================================================
# Input:  رافائل مارتینو بیر فوتبالیست .
# Masked Word:  .
# Predicted Word:  .
# رافايل مارتینو بیر فوتبالیست., confidence: 0.9996551275253296
# Predicted Word:  !
# رافايل مارتینو بیر فوتبالیست!, confidence: 0.0001835481234593317
# Predicted Word:  ؟
# رافايل مارتینو بیر فوتبالیست ؟, confidence: 0.00013018031313549727
# Predicted Word:  ##اق
# رافايل مارتینو بیر فوتبالیستاق, confidence: 1.2167005536412034e-07
# Predicted Word:  ایکی
# رافايل مارتینو بیر فوتبالیست ایکی, confidence: 1.1986807635366858e-07
# ==================================================
# Input:  چیییدن لیفی ماشێنلا تمیزلهدیکده چێخداش اولونموش لیفلر .
# Masked Word:  .
# Predicted Word:  .
# چیییدن لیفی ماشێنلا تمیزلهدیکده چێخداش اولونموش لیفلر., confidence: 0.9994187355041504
# Predicted Word:  !
# چیییدن لیفی ماشێنلا تمیزلهدیکده چێخداش اولونموش لیفلر!, confidence: 0.00047385357902385294
# Predicted Word:  ؟
# چیییدن لیفی ماشێنلا تمیزلهدیکده چێخداش اولونموش لیفلر ؟, confidence: 7.883923535700887e-05
# Predicted Word:  ##ز
# چیییدن لیفی ماشێنلا تمیزلهدیکده چێخداش اولونموش لیفلرز, confidence: 1.1122307341793203e-07
# Predicted Word:  ##سین
# چیییدن لیفی ماشێنلا تمیزلهدیکده چێخداش اولونموش لیفلرسین, confidence: 9.982911564065944e-08
# ==================================================
# Input:  دیگر بیر مقام ایسه واسطهچیلرین رئگیونا اوهلکی صفرلری ایله مۆقایصده بو دفه ائرمنیستانا گئتمهیهجکلری ایله الاقداردیر .
# Masked Word:  گئتمهیهجکلری
# Predicted Word:  کيچیریلمهسی
# دیگر بیر مقام ایسه واسطهچیلرین ريگیونا اوهلکی صفرلری ایله مۆقایصده بو دفه ايرمنیستانا کيچیریلمهسی ایله الاقداردیر., confidence: 0.1012025773525238
# Predicted Word:  اشتراکی
# دیگر بیر مقام ایسه واسطهچیلرین ريگیونا اوهلکی صفرلری ایله مۆقایصده بو دفه ايرمنیستانا اشتراکی ایله الاقداردیر., confidence: 0.04904358461499214
# Predicted Word:  الێنماسێ
# دیگر بیر مقام ایسه واسطهچیلرین ريگیونا اوهلکی صفرلری ایله مۆقایصده بو دفه ايرمنیستانا الێنماسێ ایله الاقداردیر., confidence: 0.03877880424261093
# Predicted Word:  ويریلمهسی
# دیگر بیر مقام ایسه واسطهچیلرین ريگیونا اوهلکی صفرلری ایله مۆقایصده بو دفه ايرمنیستانا ويریلمهسی ایله الاقداردیر., confidence: 0.032408226281404495
# Predicted Word:  هللی
# دیگر بیر مقام ایسه واسطهچیلرین ريگیونا اوهلکی صفرلری ایله مۆقایصده بو دفه ايرمنیستانا هللی ایله الاقداردیر., confidence: 0.018261941149830818
# ==================================================
# Input:  چیچک کیمی آچان خالێلار .
# Masked Word:  خالێلار
# Predicted Word:  ##لار
# چیچک کیمی اچانلار., confidence: 0.07439029216766357
# Predicted Word:  وار
# چیچک کیمی اچان وار., confidence: 0.03194890171289444
# Predicted Word:  اولار
# چیچک کیمی اچان اولار., confidence: 0.022588640451431274
# Predicted Word:  اولدو
# چیچک کیمی اچان اولدو., confidence: 0.01989559270441532
# Predicted Word:  اولور
# چیچک کیمی اچان اولور., confidence: 0.018865877762436867
# ==================================================
# Input:  نئفت ائمالێنێن هیاتا کئچیرن .
# Masked Word:  .
# Predicted Word:  .
# نيفت ايمالێنێن هیاتا کيچیرن., confidence: 0.9997336268424988
# Predicted Word:  !
# نيفت ايمالێنێن هیاتا کيچیرن!, confidence: 0.00012804882135242224
# Predicted Word:  ؟
# نيفت ايمالێنێن هیاتا کيچیرن ؟, confidence: 0.00011501606786623597
# Predicted Word:  ##یک
# نيفت ايمالێنێن هیاتا کيچیرنیک, confidence: 9.496972808165083e-08
# Predicted Word:  ##سین
# نيفت ايمالێنێن هیاتا کيچیرنسین, confidence: 9.03389292261636e-08
# ==================================================
# Input:  مرحوم حاج محمد نخجوانی که از فضلا و کتاب‌دوستان آذربایجان بودند و متعاقبا برادرشان حاجی حسین نخجوانی که از محققین مطرح آذربایجان بوده‌اند ، کتابخانه‌های خود را که با داشتن نسخ نفیس خطی از گرانبهاترین کتابخانه‌ها محسوب می‌شد ، وقف کتابخانه ملی کردند و بدین وسیله از نظر کمی‌ و کیفی به اهمیت آن افزودند .
# Masked Word:  آذربایجان
# Input:  چوخ شئی آنلاییر .
# Masked Word:  .
# Predicted Word:  .
# چوخ شيی انلاییر., confidence: 0.9992156028747559
# Predicted Word:  !
# چوخ شيی انلاییر!, confidence: 0.0005263023194856942
# Predicted Word:  ؟
# چوخ شيی انلاییر ؟, confidence: 0.00023316290753427893
# Predicted Word:  ##سینیز
# چوخ شيی انلاییرسینیز, confidence: 1.5141461062739836e-07
# Predicted Word:  ##یک
# چوخ شيی انلاییریک, confidence: 1.1114681797153025e-07
# ==================================================
# Input:  اونلارلا بیر یئرده اولماقدان حز آلێرام .
# Masked Word:  حز
# Predicted Word:  خبر
# اونلارلا بیر یيرده اولماقدان خبر الێرام., confidence: 0.10117264837026596
# Predicted Word:  یير
# اونلارلا بیر یيرده اولماقدان یير الێرام., confidence: 0.05733053386211395
# Predicted Word:  اجازه
# اونلارلا بیر یيرده اولماقدان اجازه الێرام., confidence: 0.03159334883093834
# Predicted Word:  نفس
# اونلارلا بیر یيرده اولماقدان نفس الێرام., confidence: 0.019572647288441658
# Predicted Word:  ازیت
# اونلارلا بیر یيرده اولماقدان ازیت الێرام., confidence: 0.01763739436864853
# ==================================================
# Input:  دمیر یولو خطلری سێرادان چێخێر .
# Masked Word:  چێخێر
# Predicted Word:  چێخێر
# دمیر یولو خطلری سێرادان چێخێر., confidence: 0.14164255559444427
# Predicted Word:  چێخێب
# دمیر یولو خطلری سێرادان چێخێب., confidence: 0.10863509029150009
# Predicted Word:  چێخدێ
# دمیر یولو خطلری سێرادان چێخدێ., confidence: 0.08994200825691223
# Predicted Word:  چێخارێر
# دمیر یولو خطلری سێرادان چێخارێر., confidence: 0.04333259537816048
# Predicted Word:  چێخمێشدێ
# دمیر یولو خطلری سێرادان چێخمێشدێ., confidence: 0.03058088943362236
# ==================================================
# Input:  باراکێن دئدیگینه گؤره ، جی ایلده اونو موسکوایا چاغێرآراق ، هئنریخ مۆللری حبث ائتمک بارهده تاپشێرێق وئریبلر .
# Masked Word:  ،
# Predicted Word:  ،
# باراکێن ديدیگینه گوره ، جی ایلده اونو موسکوایا چاغێراراق ، هينریخ مۆللری حبث ايتمک بارهده تاپشێرێق ويریبلر., confidence: 0.19525688886642456
# Predicted Word:  وه
# باراکێن ديدیگینه گوره ، جی ایلده اونو موسکوایا چاغێراراق وه هينریخ مۆللری حبث ايتمک بارهده تاپشێرێق ويریبلر., confidence: 0.10002835839986801
# Predicted Word:  ديیه
# باراکێن ديدیگینه گوره ، جی ایلده اونو موسکوایا چاغێراراق ديیه هينریخ مۆللری حبث ايتمک بارهده تاپشێرێق ويریبلر., confidence: 0.03878366947174072
# Predicted Word:  سونرا
# باراکێن ديدیگینه گوره ، جی ایلده اونو موسکوایا چاغێراراق سونرا هينریخ مۆللری حبث ايتمک بارهده تاپشێرێق ويریبلر., confidence: 0.03313792124390602
# Predicted Word:  اونلار
# باراکێن ديدیگینه گوره ، جی ایلده اونو موسکوایا چاغێراراق اونلار هينریخ مۆللری حبث ايتمک بارهده تاپشێرێق ويریبلر., confidence: 0.014648177661001682
# ==================================================
# Input:  او منیم وزیگتیمی درک ائدیردی ، بونا گؤره ده منی روحلاندێرێدێ .
# Masked Word:  درک
# Predicted Word:  حس
# او منیم وزیگتیمی حس ايدیردی ، بونا گوره ده منی روحلاندێرێدێ., confidence: 0.07097452878952026
# Predicted Word:  طلب
# او منیم وزیگتیمی طلب ايدیردی ، بونا گوره ده منی روحلاندێرێدێ., confidence: 0.05764776095747948
# Predicted Word:  داوام
# او منیم وزیگتیمی داوام ايدیردی ، بونا گوره ده منی روحلاندێرێدێ., confidence: 0.04122764989733696
# Predicted Word:  قبول
# او منیم وزیگتیمی قبول ايدیردی ، بونا گوره ده منی روحلاندێرێدێ., confidence: 0.03942044451832771
# Predicted Word:  حساب
# او منیم وزیگتیمی حساب ايدیردی ، بونا گوره ده منی روحلاندێرێدێ., confidence: 0.02950419671833515
# ==================================================
